# %% [markdown]
# # Sallve

# %%
import sys
import os
import re
import json
import time
import unicodedata
import csv
from urllib.parse import urljoin, urlparse, parse_qs, urlencode
from pathlib import Path
from typing import List, Dict, Optional

from bs4 import BeautifulSoup

sys.path.append(os.path.abspath("./../models"))

from skin import (
    SKIN_TYPE_CANONICAL_ORDER,
    SKIN_TYPE_SYNONYMS_PT,
)

from exclude import (
    EXCLUDE_KEYWORDS,
)

from ingredient import (
    INGREDIENTES_VALIDOS,
)

from benefits import (
    BENEFIT_SYNONYMS_PT,
    BENEFIT_CANONICAL_ORDER,
)

from category import (
    CATEGORY_CANONICAL_ORDER,
    CATEGORY_HINTS,
)

# %% [markdown]
# ### Configurações Iniciais

# %%
BASE_URL = "https://www.sallve.com.br"
COLLECTION_URL = "https://www.sallve.com.br/collections/loja"


SKIN_FILTER_URLS = {
    "seca":      "https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=pele+seca",
    "mista":     "https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=pele+mista",
    "sensível":  "https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=pele+sens%C3%ADvel",
    "normal":    "https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=pele+normal",
    "oleosa":    "https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=pele+oleosa",
    "todos os tipos": "https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=todos+os+tipos+de+pele",
}

HEADERS = {
    "User-Agent": (
        "Mozilla/5.0 (Windows NT 10.0; Win64; x64) "
        "AppleWebKit/537.36 (KHTML, like Gecko) "
        "Chrome/120.0.0.0 Safari/537.36"
    )
}

IMAGES_DIR = Path("images")
IMAGES_DIR.mkdir(parents=True, exist_ok=True)

# %% [markdown]
# ## Utilitários
#
# ### Funções auxiliares para normalização de texto, remoção de acentos, tokenização dos ingredientes, nomes de arquivos e formatação de preços.

# %%
def strip_accents_lower(s: str) -> str:
    if not s:
        return ""
    s = "".join(c for c in unicodedata.normalize("NFD", s) if unicodedata.category(c) != "Mn")
    s = s.lower()
    s = s.replace("-", " ")
    s = re.sub(r"[^\w\s]", " ", s)
    s = re.sub(r"\s+", " ", s).strip()
    return s

def safe_join_url(url: str) -> str:
    return "https:" + url if url.startswith("//") else url

def tokenize_ingredientes(texto: str):

    if not texto:
        return []
    texto = texto.replace("\n", " ").replace("\r", " ")
    partes = re.split(r"[;,·•|\u2022]|(?:\s{2,})|,|\.", texto)
    return [p.strip() for p in partes if p and p.strip()]

def padroniza_por_lista(tokens, lista_validos):
    valid_norm_map = {_strip_accents_lower(v): v for v in lista_validos}
    padronizados, vistos = [], set()

    for tok in tokens:
        n = strip_accents_lower(tok)
        key = None
        
        for kn in valid_norm_map.keys():
            if n == kn or n.startswith(kn) or kn in n:
                key = kn
                break
                
        if key and key not in vistos:
            padronizados.append(valid_norm_map[key])
            vistos.add(key)
            
    return padronizados

def add_or_replace_page_param(url: str, page: int) -> str:

    parsed = urlparse(url)
    q = parse_qs(parsed.query, keep_blank_values=True)
    q["page"] = [str(page)]
    new_query = urlencode({k: v[0] if isinstance(v, list) and len(v) == 1 else v for k, v in q.items()}, doseq=True)
    return parsed._replace(query=new_query).geturl()

def sanitize_filename(name: str) -> str:

    base = strip_accents_lower(name)
    base = re.sub(r"[^a-z0-9]+", "-", base).strip("-")
    base = re.sub(r"-{2,}", "-", base)
    return base or "produto"

def normalize_price_text(txt: str) -> str | None:
    if not txt:
        return None
    
    t = re.sub(r"\s+", " ", txt).strip().replace("\xa0", " ")
    
    m = re.search(r"(?:R\$)?\s*(\d{1,3}(?:\.\d{3})*,\d{2})", t)
    if m:
        num = m.group(1).replace(".", "").replace(",", ".")
        try:
            return f"{float(num):.2f}"
        except ValueError:
            return None
    
    return None

def should_exclude_product(product_name: str) -> bool:

    if not product_name:
        return True
    
    def strip_accents(s: str) -> str:
        if not isinstance(s, str):
            s = str(s)
        return ''.join(c for c in unicodedata.normalize('NFD', s) if unicodedata.category(c) != 'Mn')
    
    product_norm = strip_accents(product_name.lower())
    
    for keyword in EXCLUDE_KEYWORDS:
        if keyword and strip_accents(keyword.lower()) in product_norm:
            return True
    
    return False

# %% [markdown]
# ##  Coleta de Links de Produtos Disponíveis

# %%
def get_product_links_from_collection(max_pages: int = 8):
    links, vistos = [], set()
    for page in range(1, max_pages + 1):
        url = f"{COLLECTION_URL}?page={page}"
        try:
            r = requests.get(url, headers=HEADERS, timeout=30)
            if r.status_code != 200:
                break
            soup = BeautifulSoup(r.content, "html.parser")
            for a in soup.find_all("a", href=True):
                href = a["href"]
                if "/products/" in href:
                    full = urljoin(BASE_URL, href)
                    if full not in vistos:
                        vistos.add(full)
                        links.append(full)
            time.sleep(0.7)
        except Exception as e:
            print(f"[get_product_links_from_collection] Erro na página {page}: {e}")
            break
    return links

# %% [markdown]
# ## Ingredientes

# %%
def extract_ingredients(soup: BeautifulSoup) -> str:

    collected_ingredients = []
    
    ingredients_section = soup.find("div", class_=re.compile(r"\btabcontent\b.*\bingredients\b", re.I))
    
    if ingredients_section:

        header_elements = ingredients_section.find_all("h2")
        for header in header_elements:
            header_text = header.get_text(" ", strip=True)
            if header_text:
                collected_ingredients.append(header_text)
        
        ingredients_summary = ingredients_section.find("div", class_=re.compile(r"\bingredients_resume\b", re.I))
        if ingredients_summary:
            full_content = ingredients_summary.get_text("\n", strip=True)
            normalized_content = strip_accents_lower(full_content)
            
            main_ingredients_start = normalized_content.find("ingredientes:")
            if main_ingredients_start != -1:
                main_ingredients_section = full_content[main_ingredients_start + len("ingredientes:"):]
                
                portuguese_section_markers = ["ingredientes em portugues:", "ingredientes em português:"]
                for section_marker in portuguese_section_markers:
                    marker_position = strip_accents_lower(main_ingredients_section).find(section_marker)
                    if marker_position != -1:
                        main_ingredients_section = main_ingredients_section[:marker_position]
                        break
                
                main_ingredients_tokens = tokenize_ingredientes(main_ingredients_section)
                collected_ingredients.extend(main_ingredients_tokens)
            
            portuguese_section_keys = ["ingredientes em portugues:", "ingredientes em português:"]
            for portuguese_key in portuguese_section_keys:
                portuguese_start = normalized_content.find(portuguese_key)
                if portuguese_start != -1:
                    portuguese_section = full_content[portuguese_start + len(portuguese_key):]
                    portuguese_tokens = tokenize_ingredientes(portuguese_section)
                    collected_ingredients.extend(portuguese_tokens)
                    break
    
    filtered_ingredients = []
    for ingredient_token in collected_ingredients:
        if not ingredient_token:
            continue
        
        cleaned_ingredient = ingredient_token.strip().strip(":").strip()
        if not cleaned_ingredient:
            continue
        
        word_count = len(cleaned_ingredient.split())
        has_separators = any(separator in cleaned_ingredient for separator in [",", ";"])
        
        if word_count > 8 and not has_separators:
            continue
        
        filtered_ingredients.append(cleaned_ingredient)
    standardized_ingredients = padroniza_por_lista(filtered_ingredients, INGREDIENTES_VALIDOS)
    
    return "; ".join(standardized_ingredients)

# %% [markdown]
# ## Benefícios

# %%
def standardize_benefits(benefit_texts: List[str]) -> List[str]:
    if not benefit_texts:
        return []
    
    found_benefits = set()
    
    normalized_synonyms = {
        canonical: [_strip_accents_lower(synonym) for synonym in patterns if synonym]
        for canonical, patterns in BENEFIT_SYNONYMS_PT.items()
    }
    
    for text in benefit_texts:
        normalized_text = strip_accents_lower(text)
        
        for canonical, patterns in normalized_synonyms.items():
            if any(pattern in normalized_text for pattern in patterns):
                found_benefits.add(canonical)
    
    if BENEFIT_CANONICAL_ORDER:
        order_mapping = {name: index for index, name in enumerate(BENEFIT_CANONICAL_ORDER)}
        return sorted(list(found_benefits), key=lambda x: order_mapping.get(x, 999))
    
    return sorted(list(found_benefits))

def extract_beneficios(soup: BeautifulSoup) -> str:
 
    benefit_candidates = []
    for details in soup.find_all("details", class_=re.compile(r"\bDifferentials\b", re.I)):
        for list_item in details.find_all("li"):
            text = list_item.get_text(" ", strip=True)
            if not text:
                continue
            
            text_normalized = strip_accents_lower(text)
            
            if re.fullmatch(r"\d+(?:[.,]\d+)?", text_normalized):
                continue
            
            excluded_words = ["ponto", "pontos", "minha sallve"]
            if any(word in text_normalized for word in excluded_words):
                continue
            
            if len(text) <= 200:
                benefit_candidates.append(text)
    
    if not benefit_candidates:
        main_content = soup.find("article", class_=re.compile(r"\bRegularMain__content\b"))
        search_area = main_content or soup
        
        for list_item in search_area.find_all("li"):
            text = list_item.get_text(" ", strip=True)
            if text and len(text) <= 160:
                benefit_candidates.append(text)
    
    standardized_benefits = standardize_benefits(benefit_candidates)
    return "; ".join(standardized_benefits)

# %% [markdown]
# ## Imagem

# %%
def select_best_image_from_srcset(srcset: str) -> str:

    best_url, best_width = None, -1
    
    for part in srcset.split(","):
        part = part.strip()
        if not part:
            continue
        
        width_match = re.match(r"(.+?)\s+(\d+)w", part)
        if width_match:
            url, width = width_match.group(1).strip(), int(width_match.group(2))
            if width > best_width:
                best_url, best_width = url, width
        else:
            if best_url is None:
                best_url = part
    
    return best_url

def extract_image_url(soup: BeautifulSoup) -> Optional[str]:

    image_candidates = []
    
    main_image = soup.find("img", class_=re.compile(r"\bview__image\b", re.I))
    if main_image:
        if main_image.get("srcset"):
            image_candidates.append(select_best_image_from_srcset(main_image["srcset"]))
        if main_image.get("src"):
            image_candidates.append(main_image["src"])
    
    if not image_candidates:
        for img in soup.find_all("img"):
            class_names = " ".join(img.get("class", []))
            relevant_keywords = ["product", "image", "gallery", "media", "hero", "view"]
            
            if re.search(r"(" + "|".join(relevant_keywords) + ")", class_names, re.I):
                if img.get("srcset"):
                    image_candidates.append(select_best_image_from_srcset(img["srcset"]))
                if img.get("src"):
                    image_candidates.append(img.get("src"))
    
    if not image_candidates:
        og_image = soup.find("meta", property="og:image")
        if og_image and og_image.get("content"):
            image_candidates.append(og_image["content"])
    
    for url in image_candidates:
        if not url:
            continue
        
        corrected_url = safe_join_url(url.strip())
        return urljoin(BASE_URL, corrected_url)
    
    return None

def detect_image_extension(url: str) -> str:

    if not url:
        return ".jpg"
    
    path = urlparse(url).path
    extension = os.path.splitext(path)[1].lower()
    
    supported_extensions = [".jpg", ".jpeg", ".png", ".webp", ".gif"]
    if extension in supported_extensions:
        return ".jpg" if extension == ".jpeg" else extension
    
    return ".jpg"  

def download_image(image_url: str, product_name: str) -> Optional[str]:

    if not image_url:
        return None
    
    try:

        response = requests.get(image_url, headers=HEADERS, timeout=40)
        response.raise_for_status()
        
        extension = detect_image_extension(image_url)
        base_filename = sanitize_filename(product_name)
        filename = f"{base_filename}{extension}"
        
        destination = IMAGES_DIR / filename
        counter = 1
        while destination.exists():
            filename = f"{base_filename}-{counter}{extension}"
            destination = IMAGES_DIR / filename
            counter += 1
        
        with open(destination, "wb") as file:
            file.write(response.content)
        
        return filename
    
    except Exception as error:
        print(f"[download_image] Falha ao baixar {image_url}: {error}")
        return None

# %% [markdown]
# # Preço e tamanho

# %%
def extract_price(soup: BeautifulSoup) -> Optional[str]:

    for cls_pat in [r"\bTotalPrice\b", r"\bTotalPrice__CTA\b"]:
        el = soup.find(["strong", "span"], class_=re.compile(cls_pat, re.I))
        if el and el.get_text(strip=True):
            p = normalize_price_text(el.get_text(" ", strip=True))
            if p:
                return p
    box = soup.find(class_=re.compile(r"\bProductPrice\b", re.I))
    if box:
        p = normalize_price_text(box.get_text(" ", strip=True))
        if p:
            return p
        strong = box.find("strong")
        if strong:
            p = normalize_price_text(strong.get_text(" ", strip=True))
            if p:
                return p
    generic = soup.find(class_=re.compile(r"price", re.I))
    if generic:
        p = normalize_price_text(generic.get_text(" ", strip=True))
        if p:
            return p
    p = normalize_price_text(soup.get_text(" ", strip=True))
    return p

def extract_size(soup: BeautifulSoup) -> Optional[str]:
    size_element = soup.find("span", class_=re.compile(r"\bProductWeight\b", re.I))
    
    if size_element:
        return size_element.get_text(strip=True)
    for alt in [
        soup.find(class_=re.compile(r"weight", re.I)),
        soup.find(class_=re.compile(r"size", re.I)),
        soup.find(class_=re.compile(r"volume", re.I)),
        soup.find(class_=re.compile(r"quantity", re.I)),
    ]:
        if alt and alt.get_text(strip=True):
            text = alt.get_text(strip=True)
            m = re.search(r"\d+\,?\d*\s*(?:ml|g|mg|kg|l|oz)", text, re.I)
            if m:
                return m.group()
    return None

# %% [markdown]
# ## Nome e subtítulo

# %%
def extract_subtitle(soup: BeautifulSoup) -> Optional[str]:

    for sel in [
        "p.ProductSubtitle", "p.product-subtitle",
        ".product__subtitle", ".product__text", ".product__text.inline-richtext",
        ".ProductSummary", ".ProductDescription p",
    ]:
        node = soup.select_one(sel)
        if node and node.get_text(strip=True):
            st = node.get_text(" ", strip=True)
            return st if len(st) <= 220 else st[:220]
    return None

def extract_name(soup: BeautifulSoup) -> Optional[str]:
    name_element = soup.find("span", id="ProductNameTitle")
    if name_element and name_element.get_text(strip=True):
        return name_element.get_text(strip=True)
    for alt in [
        soup.find("h1"),
        soup.find("h2"),
        soup.find("title"),
        soup.find(class_=re.compile(r"product.*title", re.I)),
        soup.find(class_=re.compile(r"\bname\b", re.I)),
    ]:
        if alt and alt.get_text(strip=True):
            return alt.get_text(strip=True)
    return None

def fetch_soup(url: str) -> Optional[BeautifulSoup]:
    try:
        r = requests.get(url, headers=HEADERS, timeout=30)
        if r.status_code != 200:
            return None
        return BeautifulSoup(r.content, "html.parser")
    except Exception as e:
        print(f"[fetch_soup] Erro em {url}: {e}")
        return None

# %% [markdown]
# ## Categoria  e Tipos de Pele

# %%
_CAT_ORDER_MAP = {c: i for i, c in enumerate(CATEGORY_CANONICAL_ORDER)}

def norm_plain(s: str) -> str:
    return strip_accents_lower(s or "")

def classify_category(name: str, description: str | None = None) -> Optional[str]:
    txt = norm_plain(f"{name or ''} {description or ''}")
    hits = []
    for cat, needles in CATEGORY_HINTS.items():
        for needle in needles:
            if norm_plain(needle) and norm_plain(needle) in txt:
                hits.append(cat)
                break
    if not hits:
        return None
    hits.sort(key=lambda c: CAT_ORDER_MAP.get(c, 10_000))
    return hits[0]

_SKIN_SYNONYMS_NORM = {
    canonico: [_strip_accents_lower(x) for x in lst if x]
    for canonico, lst in SKIN_TYPE_SYNONYMS_PT.items()
}
_SKIN_ORDER_MAP = {name: i for i, name in enumerate(SKIN_TYPE_CANONICAL_ORDER or [])}

def classify_skin_types_from_strings(*strings: str) -> List[str]:
    big = strip_accents_lower(" ".join(s for s in strings if s))
    found = set()
    for canonico, pats in SKIN_SYNONYMS_NORM.items():
        if any(p and p in big for p in pats):
            found.add(canonico)
    if not found:
        return []
    return sorted(found, key=lambda x: SKIN_ORDER_MAP.get(x, 10_000))

# %% [markdown]
# ## Extração

# %%
def extract_product_data_from_soup(soup: BeautifulSoup, product_url: str, product_name: str) -> Dict:

    product_subtitle = extract_subtitle(soup)
    product_benefits = extract_beneficios(soup) or ""
    product_ingredients = extract_ingredients(soup) or ""
    product_price = extract_price(soup) or ""
    product_size = extract_size(soup) or ""

    product_category = classify_category(product_name, product_subtitle) or ""

    detected_skin_types = classify_skin_types_from_strings(
        product_name, 
        product_subtitle or "", 
        product_benefits
    )

    product_data = {
        "marca": "sallve",
        "nome": product_name,
        "subtitulo": product_subtitle,
        "categoria": product_category,
        "quantidade": product_size,
        "preco": product_price,
        "ingredientes": product_ingredients,
        "beneficios": product_benefits,
        "tipo_pele": "; ".join(detected_skin_types) if detected_skin_types else "",
        "imagem": "",
    }

    image_url = extract_image_url(soup)
    if image_url:
        downloaded_image_filename = download_image(image_url, product_name)
        if downloaded_image_filename:
            product_data["imagem"] = downloaded_image_filename

    return product_data

def scrape_sallve_products() -> List[Dict]:

    print("____________________________________________________________________________________________________________")

    print("WEB SCRAPING Sallve...")
    
    product_links = get_product_links_from_collection(max_pages=8)
    if not product_links:
        print("Nenhum produto encontrado na coleção. (Checar HTML/seletores)")
        return []

    print(f"Encontrados {len(product_links)} links de produto (antes de filtro).")
    collected_products = []

    for current_index, product_url in enumerate(product_links, 1):
        print(f" [{current_index}/{len(product_links)}] {product_url}")
        
        page_soup = fetch_soup(product_url)
        if not page_soup:
            print("\n Falha ao abrir página.")
            continue

        product_name = extract_name(page_soup)
        if not product_name:
            print("\n Nome não encontrado.")
            continue

        if should_exclude_product(product_name):
            print(f"\nExcluído por keyword (models): {product_name}")
            continue

        product_data = extract_product_data_from_soup(page_soup, product_url, product_name)
        collected_products.append(product_data)
        print(f" \nOK: {product_name}")
        
        time.sleep(0.7)

    print(f"Total pós-filtro: {len(collected_products)}")
    return collected_products

def collect_collection_products_with_pagination(collection_url: str, max_pages: int = 20):

    discovered_product_names = set()
    
    for current_page in range(1, max_pages + 1):
        paginated_url = add_or_replace_page_param(collection_url, current_page)
        
        try:
            response = requests.get(paginated_url, headers=HEADERS, timeout=30)
            if response.status_code != 200:
                break
            
            page_soup = BeautifulSoup(response.content, "html.parser")
            product_links = page_soup.find_all("a", href=True)
            
            products_found_on_page = 0
            
            for link_element in product_links:
                href_attribute = link_element["href"]
                
                if "/products/" in href_attribute:
                    link_text = link_element.get_text(" ", strip=True) or ""
                    if not link_text:
                        image_element = link_element.find("img", alt=True)
                        if image_element and image_element.get("alt"):
                            link_text = image_element["alt"]
                    
                    if link_text:
                        products_found_on_page += 1
                        normalized_name = strip_accents_lower(link_text)
                        discovered_product_names.add(normalized_name)
            
            if products_found_on_page == 0:
                break
                
            time.sleep(0.5)
            
        except Exception as e:
            print(f"[skin-type-collect] Erro na página: {paginated_url} -> {e}")
            break
    
    return discovered_product_names

def enrich_with_skin_types(products: List[Dict]) -> List[Dict]:

    if not products:
        return products

    print("\nColetando tipos de pele via filtros da Sallve...")
    
    name_to_product_indices = {}
    for product_index, product_data in enumerate(products):
        normalized_name = strip_accents_lower(product_data.get("nome", ""))
        if normalized_name:
            name_to_product_indices.setdefault(normalized_name, set()).add(product_index)

    universal_skin_type_products = set()
    
    if "todos os tipos" in SKIN_FILTER_URLS:
        universal_skin_type = "todos os tipos"
        filter_url = SKIN_FILTER_URLS[universal_skin_type]
        print(f" - Filtro '{universal_skin_type}': {filter_url}")
        
        discovered_names = collect_collection_products_with_pagination(filter_url, max_pages=20)
        print(f"   · {len(discovered_names)} nome(s) coletado(s)")
        
        for normalized_name in discovered_names:
            if normalized_name in name_to_product_indices:
                for product_index in name_to_product_indices[normalized_name]:
                    universal_skin_type_products.add(product_index)
                    products[product_index]["tipo_pele"] = "todos os tipos"
        
        time.sleep(0.6)

    for skin_type_canonical, filter_url in SKIN_FILTER_URLS.items():
        if skin_type_canonical == "todos os tipos":
            continue
            
        discovered_names = collect_collection_products_with_pagination(filter_url, max_pages=20)
        
        for normalized_name in discovered_names:
            if normalized_name in name_to_product_indices:
                for product_index in name_to_product_indices[normalized_name]:
                    if product_index in universal_skin_type_products:
                        continue
                        
                    current_skin_types = products[product_index].get("tipo_pele", "") or ""
                    existing_types = [skin_type.strip() for skin_type in current_skin_types.split(";") if skin_type.strip()]
                    
                    if skin_type_canonical not in existing_types:
                        existing_types.append(skin_type_canonical)
                    
                    if SKIN_TYPE_CANONICAL_ORDER:
                        skin_type_order = {skin_type: index for index, skin_type in enumerate(SKIN_TYPE_CANONICAL_ORDER)}
                        existing_types = sorted(existing_types, key=lambda x: skin_type_order.get(x, 999))
                    
                    products[product_index]["tipo_pele"] = "; ".join(existing_types)
        
        time.sleep(0.6)

    for product_index, product_data in enumerate(products):
        current_skin_type = (product_data.get("tipo_pele") or "").strip()
        if not current_skin_type:
            product_data["tipo_pele"] = "todos os tipos"

    return products

# %% [markdown]
# ## Arquivo e Main

# %%
def save_data(products_data: List[Dict]):
    if not products_data:
        print("\nNenhum dado para salvar.")
        return

    clean = []
    for p in products_data:
        clean.append({
            "marca": p.get("marca"),
            "nome": p.get("nome"),
            "subtitulo": p.get("subtitulo"),
            "categoria": p.get("categoria"),
            "quantidade": p.get("quantidade"),
            "preco": p.get("preco"),
            "beneficios": p.get("beneficios"),
            "ingredientes": p.get("ingredientes"),
            "tipo_pele": p.get("tipo_pele"),
            "imagem": p.get("imagem"),
        })

    with open("sallve_products.json", "w", encoding="utf-8") as f:
        json.dump(clean, f, ensure_ascii=False, indent=2)
    
    print(f"JSON: sallve_products.json ({len(clean)} produtos)")

if __name__ == "__main__":
    try:
        data = scrape_sallve_products()
        data = enrich_with_skin_types(data)
        save_data(data)
        print("____________________________________________________________________________________________________________")
        print(f"\nFim da execução! Produtos extraídos: {len(data)}")
        print(f"Imagens salvas em: {IMAGES_DIR.resolve()}")
        print("____________________________________________________________________________________________________________")

    except Exception as e:
        print(f"\nERRO: {e}")
# Out:
# ____________________________________________________________________________________________________________
# WEB SCRAPING Sallve...
# Encontrados 146 links de produto (antes de filtro).
#  [1/146] https://www.sallve.com.br/products/bastao-antioxidante-para-olhos
# Encontrados 146 links de produto (antes de filtro).
#  [1/146] https://www.sallve.com.br/products/bastao-antioxidante-para-olhos
#
# OK: Bastão Antiolheiras Antioxidante
#
# OK: Bastão Antiolheiras Antioxidante
#  [2/146] https://www.sallve.com.br/products/kit-tudinho
#  [2/146] https://www.sallve.com.br/products/kit-tudinho
#
# Excluído por keyword (models): Kit Tudinho
#  [3/146] https://www.sallve.com.br/collections/kits/products/kit-basicao
#
# Excluído por keyword (models): Kit Tudinho
#  [3/146] https://www.sallve.com.br/collections/kits/products/kit-basicao
#
# Excluído por keyword (models): Kit Basicão
#  [4/146] https://www.sallve.com.br/products/protetor-solar-bastao-com-cor-antimanchas-fps-90
#
# Excluído por keyword (models): Kit Basicão
#  [4/146] https://www.sallve.com.br/products/protetor-solar-bastao-com-cor-antimanchas-fps-90
#
# OK: Protetor Solar Bastão com Cor Antimanchas FPS 90
#
# OK: Protetor Solar Bastão com Cor Antimanchas FPS 90
#  [5/146] https://www.sallve.com.br/products/bastao-antiatrito
#  [5/146] https://www.sallve.com.br/products/bastao-antiatrito
#
# OK: Bastão Antiatrito
#
# OK: Bastão Antiatrito
#  [6/146] https://www.sallve.com.br/products/protetor-solar-bastao-fps60-muito-resistente
#  [6/146] https://www.sallve.com.br/products/protetor-solar-bastao-fps60-muito-resistente
#
# OK: Protetor Solar Bastão FPS 60 Muito Resistente
#
# OK: Protetor Solar Bastão FPS 60 Muito Resistente
#  [7/146] https://www.sallve.com.br/products/bastao-antioleosidade
#  [7/146] https://www.sallve.com.br/products/bastao-antioleosidade
#
# OK: Bastão Antioleosidade
#
# OK: Bastão Antioleosidade
#  [8/146] https://www.sallve.com.br/products/dupla-protecao-em-bastao
#  [8/146] https://www.sallve.com.br/products/dupla-protecao-em-bastao
#
# Excluído por keyword (models): Dupla Proteção em Bastão
#  [9/146] https://www.sallve.com.br/products/dupla-rotina-pratica
#
# Excluído por keyword (models): Dupla Proteção em Bastão
#  [9/146] https://www.sallve.com.br/products/dupla-rotina-pratica
#
# Excluído por keyword (models): dupla rotina prática
#  [10/146] https://www.sallve.com.br/products/limpador-enzimatico-em-po
#
# Excluído por keyword (models): dupla rotina prática
#  [10/146] https://www.sallve.com.br/products/limpador-enzimatico-em-po
#
# OK: Limpador Enzimático em Pó
#
# OK: Limpador Enzimático em Pó
#  [11/146] https://www.sallve.com.br/products/serum-para-cilios
#  [11/146] https://www.sallve.com.br/products/serum-para-cilios
#
# OK: Sérum para Cílios
#
# OK: Sérum para Cílios
#  [12/146] https://www.sallve.com.br/products/protetor-solar-bastao-antioleosidade
#  [12/146] https://www.sallve.com.br/products/protetor-solar-bastao-antioleosidade
#
# OK: Protetor Solar Bastão Antioleosidade
#
# OK: Protetor Solar Bastão Antioleosidade
#  [13/146] https://www.sallve.com.br/products/serum-antiolheiras
#  [13/146] https://www.sallve.com.br/products/serum-antiolheiras
#
# OK: Sérum Antiolheiras
#
# OK: Sérum Antiolheiras
#  [14/146] https://www.sallve.com.br/products/creme-retexturizador-noturno
#  [14/146] https://www.sallve.com.br/products/creme-retexturizador-noturno
#
# OK: Creme Retexturizador Noturno
#
# OK: Creme Retexturizador Noturno
#  [15/146] https://www.sallve.com.br/products/hidratante-antioleosidade
#  [15/146] https://www.sallve.com.br/products/hidratante-antioleosidade
#
# OK: Hidratante Antioleosidade
#
# OK: Hidratante Antioleosidade
#  [16/146] https://www.sallve.com.br/products/super-niacinamida-20
#  [16/146] https://www.sallve.com.br/products/super-niacinamida-20
#
# OK: Super Niacinamida 20%
#
# OK: Super Niacinamida 20%
#  [17/146] https://www.sallve.com.br/products/super-pro-colageno-10
#  [17/146] https://www.sallve.com.br/products/super-pro-colageno-10
#
# OK: Super Pró-Colágeno 10%
#
# OK: Super Pró-Colágeno 10%
#  [18/146] https://www.sallve.com.br/products/retinol-serum-antissinais
#  [18/146] https://www.sallve.com.br/products/retinol-serum-antissinais
#
# OK: Sérum Antissinais Retinol Puro 0.3%
#
# OK: Sérum Antissinais Retinol Puro 0.3%
#  [19/146] https://www.sallve.com.br/products/acido-hialuronico-hidratante-firmador
#  [19/146] https://www.sallve.com.br/products/acido-hialuronico-hidratante-firmador
#
# OK: Ácido Hialurônico Hidratante Firmador
#
# OK: Ácido Hialurônico Hidratante Firmador
#  [20/146] https://www.sallve.com.br/products/vitamina-c-antioxidante-hidratante
#  [20/146] https://www.sallve.com.br/products/vitamina-c-antioxidante-hidratante
#
# OK: Vitamina C Antioxidante Hidratante
#
# OK: Vitamina C Antioxidante Hidratante
#  [21/146] https://www.sallve.com.br/products/serum-antiacne
#  [21/146] https://www.sallve.com.br/products/serum-antiacne
#
# OK: Sérum Antiacne
#
# OK: Sérum Antiacne
#  [22/146] https://www.sallve.com.br/products/serum-uniformizador
#  [22/146] https://www.sallve.com.br/products/serum-uniformizador
#
# OK: Sérum Uniformizador
#
# OK: Sérum Uniformizador
#  [23/146] https://www.sallve.com.br/products/limpador-antioleosidade
#  [23/146] https://www.sallve.com.br/products/limpador-antioleosidade
#
# OK: Limpador Antioleosidade
#
# OK: Limpador Antioleosidade
#  [24/146] https://www.sallve.com.br/products/limpador-facial
#  [24/146] https://www.sallve.com.br/products/limpador-facial
#
# OK: Limpador Facial
#
# OK: Limpador Facial
#  [25/146] https://www.sallve.com.br/products/protetor-solar-toque-seco-fps50
#  [25/146] https://www.sallve.com.br/products/protetor-solar-toque-seco-fps50
#
# OK: Protetor Solar Toque Seco FPS 50
#
# OK: Protetor Solar Toque Seco FPS 50
#  [26/146] https://www.sallve.com.br/products/tonico-antiacne
#  [26/146] https://www.sallve.com.br/products/tonico-antiacne
#
# OK: Tônico Antiacne
#
# OK: Tônico Antiacne
#  [27/146] https://www.sallve.com.br/products/super-vitamina-c-20
#  [27/146] https://www.sallve.com.br/products/super-vitamina-c-20
#
# OK: Super Vitamina C 20%
#
# OK: Super Vitamina C 20%
#  [28/146] https://www.sallve.com.br/products/dupla-renovacao-e-protecao-antioleosidade
#  [28/146] https://www.sallve.com.br/products/dupla-renovacao-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Renovação e Proteção Antioleosidade
#  [29/146] https://www.sallve.com.br/products/dupla-bastao-antioleosidade-dia-e-noite
#
# Excluído por keyword (models): Dupla Renovação e Proteção Antioleosidade
#  [29/146] https://www.sallve.com.br/products/dupla-bastao-antioleosidade-dia-e-noite
#
# Excluído por keyword (models): Dupla Bastão Antioleosidade Dia e Noite
#  [30/146] https://www.sallve.com.br/products/dupla-rotina-noturna
#
# Excluído por keyword (models): Dupla Bastão Antioleosidade Dia e Noite
#  [30/146] https://www.sallve.com.br/products/dupla-rotina-noturna
#
# Excluído por keyword (models): Dupla Rotina Noturna
#  [31/146] https://www.sallve.com.br/products/dupla-acorda-e-vai-antioleosidade
#
# Excluído por keyword (models): Dupla Rotina Noturna
#  [31/146] https://www.sallve.com.br/products/dupla-acorda-e-vai-antioleosidade
#
# Excluído por keyword (models): Dupla Acorda e Vai Antioleosidade
#  [32/146] https://www.sallve.com.br/products/dupla-sono-renovador
#
# Excluído por keyword (models): Dupla Acorda e Vai Antioleosidade
#  [32/146] https://www.sallve.com.br/products/dupla-sono-renovador
#
# Excluído por keyword (models): Dupla Sono Renovador
#  [33/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Sono Renovador
#  [33/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Antiolheiras e Proteção Antioleosidade
#  [34/146] https://www.sallve.com.br/products/dupla-renovacao-e-protecao-com-cor
#
# Excluído por keyword (models): Dupla Antiolheiras e Proteção Antioleosidade
#  [34/146] https://www.sallve.com.br/products/dupla-renovacao-e-protecao-com-cor
#
# Excluído por keyword (models): Dupla Renovação e Proteção - com Cor
#  [35/146] https://www.sallve.com.br/products/dupla-pele-sequinha-dia-e-noite
#
# Excluído por keyword (models): Dupla Renovação e Proteção - com Cor
#  [35/146] https://www.sallve.com.br/products/dupla-pele-sequinha-dia-e-noite
#
# Excluído por keyword (models): Dupla Pele Sequinha Dia e Noite
#  [36/146] https://www.sallve.com.br/products/dupla-acorda-e-vai
#
# Excluído por keyword (models): Dupla Pele Sequinha Dia e Noite
#  [36/146] https://www.sallve.com.br/products/dupla-acorda-e-vai
#
# Excluído por keyword (models): Dupla Acorda e Vai
#  [37/146] https://www.sallve.com.br/products/dupla-hidratacao-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Acorda e Vai
#  [37/146] https://www.sallve.com.br/products/dupla-hidratacao-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Hidratação e Proteção Antioleosidade
#  [38/146] https://www.sallve.com.br/products/dupla-pele-descansada
#
# Excluído por keyword (models): Dupla Hidratação e Proteção Antioleosidade
#  [38/146] https://www.sallve.com.br/products/dupla-pele-descansada
#
# Excluído por keyword (models): Dupla Pele Descansada
#  [39/146] https://www.sallve.com.br/products/dupla-limpeza-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Pele Descansada
#  [39/146] https://www.sallve.com.br/products/dupla-limpeza-e-protecao-antioleosidade
#
# Excluído por keyword (models): Dupla Limpeza e Proteção Antioleosidade
#  [40/146] https://www.sallve.com.br/products/dupla-renovacao-e-protecao
#
# Excluído por keyword (models): Dupla Limpeza e Proteção Antioleosidade
#  [40/146] https://www.sallve.com.br/products/dupla-renovacao-e-protecao
#
# Excluído por keyword (models): Dupla Renovação e Proteção
#  [41/146] https://www.sallve.com.br/products/dupla-pele-mais-lisa
#
# Excluído por keyword (models): Dupla Renovação e Proteção
#  [41/146] https://www.sallve.com.br/products/dupla-pele-mais-lisa
#
# Excluído por keyword (models): Dupla Pele Mais Lisa
#  [42/146] https://www.sallve.com.br/products/dupla-verao-na-bolsa
#
# Excluído por keyword (models): Dupla Pele Mais Lisa
#  [42/146] https://www.sallve.com.br/products/dupla-verao-na-bolsa
#
# Excluído por keyword (models): Dupla de Treino
#  [43/146] https://www.sallve.com.br/products/kit-rotina-antioleosidade
#
# Excluído por keyword (models): Dupla de Treino
#  [43/146] https://www.sallve.com.br/products/kit-rotina-antioleosidade
#
# Excluído por keyword (models): kit rotina completa antioleosidade
#  [44/146] https://www.sallve.com.br/products/trio-bastao
#
# Excluído por keyword (models): kit rotina completa antioleosidade
#  [44/146] https://www.sallve.com.br/products/trio-bastao
#
# Excluído por keyword (models): Trio Bastão
#  [45/146] https://www.sallve.com.br/products/dupla-renovacao-e-hidratacao
#
# Excluído por keyword (models): Trio Bastão
#  [45/146] https://www.sallve.com.br/products/dupla-renovacao-e-hidratacao
#
# Excluído por keyword (models): Dupla Renovação e Hidratação
#  [46/146] https://www.sallve.com.br/products/dupla-rotina-expressa
#
# Excluído por keyword (models): Dupla Renovação e Hidratação
#  [46/146] https://www.sallve.com.br/products/dupla-rotina-expressa
#
# Excluído por keyword (models): Dupla Rotina Expressa
#  [47/146] https://www.sallve.com.br/products/dupla-vitamina-c
#
# Excluído por keyword (models): Dupla Rotina Expressa
#  [47/146] https://www.sallve.com.br/products/dupla-vitamina-c
#
# Excluído por keyword (models): Dupla Vitamina C
#  [48/146] https://www.sallve.com.br/products/dupla-cuidado-diario-pele-oleosa
#
# Excluído por keyword (models): Dupla Vitamina C
#  [48/146] https://www.sallve.com.br/products/dupla-cuidado-diario-pele-oleosa
#
# Excluído por keyword (models): dupla cuidado diário - pele oleosa
#  [49/146] https://www.sallve.com.br/products/dupla-antioleosidade-dia-e-noite
#
# Excluído por keyword (models): dupla cuidado diário - pele oleosa
#  [49/146] https://www.sallve.com.br/products/dupla-antioleosidade-dia-e-noite
#
# Excluído por keyword (models): dupla antioleosidade dia e noite
#  [50/146] https://www.sallve.com.br/products/kit-antioleosidade
#
# Excluído por keyword (models): dupla antioleosidade dia e noite
#  [50/146] https://www.sallve.com.br/products/kit-antioleosidade
#
# Excluído por keyword (models): Kit Antioleosidade
#  [51/146] https://www.sallve.com.br/products/dupla-tratamento-area-dos-olhos
#
# Excluído por keyword (models): Kit Antioleosidade
#  [51/146] https://www.sallve.com.br/products/dupla-tratamento-area-dos-olhos
#
# Excluído por keyword (models): Dupla Tratamento Área dos Olhos
#  [52/146] https://www.sallve.com.br/products/dupla-olhar-renovado
#
# Excluído por keyword (models): Dupla Tratamento Área dos Olhos
#  [52/146] https://www.sallve.com.br/products/dupla-olhar-renovado
#
# Excluído por keyword (models): Dupla Olhar Renovado
#  [53/146] https://www.sallve.com.br/products/dupla-limpa-acorda-e-revigora
#
# Excluído por keyword (models): Dupla Olhar Renovado
#  [53/146] https://www.sallve.com.br/products/dupla-limpa-acorda-e-revigora
#
# Excluído por keyword (models): Dupla Limpa, Acorda e Revigora
#  [54/146] https://www.sallve.com.br/products/dupla-vitamina-c-pele-sensivel
#
# Excluído por keyword (models): Dupla Limpa, Acorda e Revigora
#  [54/146] https://www.sallve.com.br/products/dupla-vitamina-c-pele-sensivel
#
# Excluído por keyword (models): Dupla Vitamina C - Pele Sensível
#  [55/146] https://www.sallve.com.br/products/dupla-protecao-resistente
#
# Excluído por keyword (models): Dupla Vitamina C - Pele Sensível
#  [55/146] https://www.sallve.com.br/products/dupla-protecao-resistente
#
# Excluído por keyword (models): Dupla Proteção Resistente
#  [56/146] https://www.sallve.com.br/products/dupla-renova-e-repara
#
# Excluído por keyword (models): Dupla Proteção Resistente
#  [56/146] https://www.sallve.com.br/products/dupla-renova-e-repara
#
# Excluído por keyword (models): Dupla Renova e Repara
#  [57/146] https://www.sallve.com.br/products/dupla-colageno-e-retinol-puro-0-3
#
# Excluído por keyword (models): Dupla Renova e Repara
#  [57/146] https://www.sallve.com.br/products/dupla-colageno-e-retinol-puro-0-3
#
# Excluído por keyword (models): Dupla Colágeno e Retinol Puro 0,3%
#  [58/146] https://www.sallve.com.br/products/dupla-colageno-e-vitamina-c-20
#
# Excluído por keyword (models): Dupla Colágeno e Retinol Puro 0,3%
#  [58/146] https://www.sallve.com.br/products/dupla-colageno-e-vitamina-c-20
#
# Excluído por keyword (models): Dupla Colágeno e Vitamina C 20%
#  [59/146] https://www.sallve.com.br/products/dupla-colageno-e-niacinamida-20
#
# Excluído por keyword (models): Dupla Colágeno e Vitamina C 20%
#  [59/146] https://www.sallve.com.br/products/dupla-colageno-e-niacinamida-20
#
# Excluído por keyword (models): Dupla Colágeno e Niacinamida 20%
#  [60/146] https://www.sallve.com.br/products/dupla-niacinamida
#
# Excluído por keyword (models): Dupla Colágeno e Niacinamida 20%
#  [60/146] https://www.sallve.com.br/products/dupla-niacinamida
#
# Excluído por keyword (models): Dupla Niacinamida
#  [61/146] https://www.sallve.com.br/products/dupla-colageno-e-vitamina-c
#
# Excluído por keyword (models): Dupla Niacinamida
#  [61/146] https://www.sallve.com.br/products/dupla-colageno-e-vitamina-c
#
# Excluído por keyword (models): Dupla Colágeno e Vitamina C
#  [62/146] https://www.sallve.com.br/products/dupla-protecao-com-e-sem-cor
#
# Excluído por keyword (models): Dupla Colágeno e Vitamina C
#  [62/146] https://www.sallve.com.br/products/dupla-protecao-com-e-sem-cor
#
# Excluído por keyword (models): Dupla Proteção - com e sem cor
#  [63/146] https://www.sallve.com.br/products/retinol-puro-retinol-biomimetico
#
# Excluído por keyword (models): Dupla Proteção - com e sem cor
#  [63/146] https://www.sallve.com.br/products/retinol-puro-retinol-biomimetico
#
# Excluído por keyword (models): Dupla Retinol Dia e Noite
#  [64/146] https://www.sallve.com.br/products/dupla-retinol-e-vitamina-c-pele-sensivel
#
# Excluído por keyword (models): Dupla Retinol Dia e Noite
#  [64/146] https://www.sallve.com.br/products/dupla-retinol-e-vitamina-c-pele-sensivel
#
# Excluído por keyword (models): Dupla Retinol e Vitamina C  - Pele Sensível
#  [65/146] https://www.sallve.com.br/products/dupla-reducao-de-marcas
#
# Excluído por keyword (models): Dupla Retinol e Vitamina C  - Pele Sensível
#  [65/146] https://www.sallve.com.br/products/dupla-reducao-de-marcas
#
# Excluído por keyword (models): Dupla Redução de Marcas
#  [66/146] https://www.sallve.com.br/products/dupla-seca-e-nao-resseca
#
# Excluído por keyword (models): Dupla Redução de Marcas
#  [66/146] https://www.sallve.com.br/products/dupla-seca-e-nao-resseca
#
# Excluído por keyword (models): Dupla Seca e Não Resseca
#  [67/146] https://www.sallve.com.br/products/dupla-pele-mais-lisa-pele-sensivel
#
# Excluído por keyword (models): Dupla Seca e Não Resseca
#  [67/146] https://www.sallve.com.br/products/dupla-pele-mais-lisa-pele-sensivel
#
# Excluído por keyword (models): Dupla Pele Mais Lisa - Pele Sensível
#  [68/146] https://www.sallve.com.br/products/dupla-colageno-e-vitamina-c-pele-sensivel
#
# Excluído por keyword (models): Dupla Pele Mais Lisa - Pele Sensível
#  [68/146] https://www.sallve.com.br/products/dupla-colageno-e-vitamina-c-pele-sensivel
#
# Excluído por keyword (models): Dupla Colágeno e Vitamina C - Pele Sensível
#  [69/146] https://www.sallve.com.br/products/trio-livre-de-acne
#
# Excluído por keyword (models): Dupla Colágeno e Vitamina C - Pele Sensível
#  [69/146] https://www.sallve.com.br/products/trio-livre-de-acne
#
# Excluído por keyword (models): Trio Livre de Acne
#  [70/146] https://www.sallve.com.br/products/dupla-super-antiacne
#
# Excluído por keyword (models): Trio Livre de Acne
#  [70/146] https://www.sallve.com.br/products/dupla-super-antiacne
#
# Excluído por keyword (models): Dupla Super Antiacne
#  [71/146] https://www.sallve.com.br/products/dupla-antimarcas-dia
#
# Excluído por keyword (models): Dupla Super Antiacne
#  [71/146] https://www.sallve.com.br/products/dupla-antimarcas-dia
#
# Excluído por keyword (models): Dupla Antimarcas - Dia
#  [72/146] https://www.sallve.com.br/products/kit-antissinais-basicao
#
# Excluído por keyword (models): Dupla Antimarcas - Dia
#  [72/146] https://www.sallve.com.br/products/kit-antissinais-basicao
#
# Excluído por keyword (models): Kit Antissinais Basicão
#  [73/146] https://www.sallve.com.br/products/kit-antissinais-completao
#
# Excluído por keyword (models): Kit Antissinais Basicão
#  [73/146] https://www.sallve.com.br/products/kit-antissinais-completao
#
# Excluído por keyword (models): Kit Antissinais Completão
#  [74/146] https://www.sallve.com.br/products/kit-novos-fios
#
# Excluído por keyword (models): Kit Antissinais Completão
#  [74/146] https://www.sallve.com.br/products/kit-novos-fios
#
# Excluído por keyword (models): Dupla Novos Fios
#  [75/146] https://www.sallve.com.br/products/dupla-cuidado-diario
#
# Excluído por keyword (models): Dupla Novos Fios
#  [75/146] https://www.sallve.com.br/products/dupla-cuidado-diario
#
# Excluído por keyword (models): Dupla Cuidado Diário
#  [76/146] https://www.sallve.com.br/products/dupla-adeus-assaduras
#
# Excluído por keyword (models): Dupla Cuidado Diário
#  [76/146] https://www.sallve.com.br/products/dupla-adeus-assaduras
#
# Excluído por keyword (models): Dupla Adeus, Assaduras
#  [77/146] https://www.sallve.com.br/products/limpador-antiacne
#
# Excluído por keyword (models): Dupla Adeus, Assaduras
#  [77/146] https://www.sallve.com.br/products/limpador-antiacne
#
# OK: Limpador Antiacne
#
# OK: Limpador Antiacne
#  [78/146] https://www.sallve.com.br/products/hidratante-facial
#  [78/146] https://www.sallve.com.br/products/hidratante-facial
#
# OK: Hidratante Facial
#
# OK: Hidratante Facial
#  [79/146] https://www.sallve.com.br/products/hidratante-reparador-labial
#  [79/146] https://www.sallve.com.br/products/hidratante-reparador-labial
#
# OK: Hidratante Reparador Labial
#
# OK: Hidratante Reparador Labial
#  [80/146] https://www.sallve.com.br/products/hidratante-reparador
#  [80/146] https://www.sallve.com.br/products/hidratante-reparador
#
# OK: Hidratante Reparador
#
# OK: Hidratante Reparador
#  [81/146] https://www.sallve.com.br/products/vitamina-c-acido-hialuronico-retinol
#  [81/146] https://www.sallve.com.br/products/vitamina-c-acido-hialuronico-retinol
#
# OK: vitamina c + ácido hialurônico + retinol puro
#
# OK: vitamina c + ácido hialurônico + retinol puro
#  [82/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-antiatrito
#  [82/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-antiatrito
#
# Excluído por keyword (models): Dupla Antiolheiras e Antiatrito
#  [83/146] https://www.sallve.com.br/products/dupla-esfoliante
#
# Excluído por keyword (models): Dupla Antiolheiras e Antiatrito
#  [83/146] https://www.sallve.com.br/products/dupla-esfoliante
#
# Excluído por keyword (models): Dupla Esfoliante
#  [84/146] https://www.sallve.com.br/products/esfoliante-enzimatico
#
# Excluído por keyword (models): Dupla Esfoliante
#  [84/146] https://www.sallve.com.br/products/esfoliante-enzimatico
#
# OK: Esfoliante enzimático
#
# OK: Esfoliante enzimático
#  [85/146] https://www.sallve.com.br/products/esfoliante-hidratante-corporal
#  [85/146] https://www.sallve.com.br/products/esfoliante-hidratante-corporal
#
# Excluído por keyword (models): Esfoliante Hidratante Corporal
#  [86/146] https://www.sallve.com.br/products/hidratante-antiatrito
#
# Excluído por keyword (models): Esfoliante Hidratante Corporal
#  [86/146] https://www.sallve.com.br/products/hidratante-antiatrito
#
# OK: Hidratante Antiatrito
#
# OK: Hidratante Antiatrito
#  [87/146] https://www.sallve.com.br/products/super-acido-glicolico-10
#  [87/146] https://www.sallve.com.br/products/super-acido-glicolico-10
#
# OK: Super Ácido Glicólico 10%
#
# OK: Super Ácido Glicólico 10%
#  [88/146] https://www.sallve.com.br/products/super-acido-salicilico-2
#  [88/146] https://www.sallve.com.br/products/super-acido-salicilico-2
#
# OK: Super Ácido Salicílico 2%
#
# OK: Super Ácido Salicílico 2%
#  [89/146] https://www.sallve.com.br/products/kit-basicao-linha-antiacne
#  [89/146] https://www.sallve.com.br/products/kit-basicao-linha-antiacne
#
# Excluído por keyword (models): Kit Basicão Antiacne
#  [90/146] https://www.sallve.com.br/products/tonico-renovador
#
# Excluído por keyword (models): Kit Basicão Antiacne
#  [90/146] https://www.sallve.com.br/products/tonico-renovador
#
# OK: Tônico Renovador
#
# OK: Tônico Renovador
#  [91/146] https://www.sallve.com.br/products/dupla-verao-na-bolsa-com-cor
#  [91/146] https://www.sallve.com.br/products/dupla-verao-na-bolsa-com-cor
#
# Excluído por keyword (models): Dupla de Treino - com cor
#  [92/146] https://www.sallve.com.br/products/spray-reparador-calmante
#
# Excluído por keyword (models): Dupla de Treino - com cor
#  [92/146] https://www.sallve.com.br/products/spray-reparador-calmante
#
# OK: Spray Reparador Calmante
#
# OK: Spray Reparador Calmante
#  [93/146] https://www.sallve.com.br/products/vitamina-c-acido-salicilico
#  [93/146] https://www.sallve.com.br/products/vitamina-c-acido-salicilico
#
# OK: vitamina c + ácido salicílico
#
# OK: vitamina c + ácido salicílico
#  [94/146] https://www.sallve.com.br/products/tonico-antiqueda
#  [94/146] https://www.sallve.com.br/products/tonico-antiqueda
#
# Excluído por keyword (models): Tônico Antiqueda Capilar
#  [95/146] https://www.sallve.com.br/products/dupla-acorda-e-vai-toque-seco
#
# Excluído por keyword (models): Tônico Antiqueda Capilar
#  [95/146] https://www.sallve.com.br/products/dupla-acorda-e-vai-toque-seco
#
# Excluído por keyword (models): Dupla Acorda e Vai - toque seco
#  [96/146] https://www.sallve.com.br/products/kit-basicao
#
# Excluído por keyword (models): Dupla Acorda e Vai - toque seco
#  [96/146] https://www.sallve.com.br/products/kit-basicao
#
# Excluído por keyword (models): Kit Basicão
#  [97/146] https://www.sallve.com.br/products/dupla-livre-de-pelos-encravados
#
# Excluído por keyword (models): Kit Basicão
#  [97/146] https://www.sallve.com.br/products/dupla-livre-de-pelos-encravados
#
# Excluído por keyword (models): Dupla Livre de Pelos Encravados
#  [98/146] https://www.sallve.com.br/products/dupla-cuidado-corporal
#
# Excluído por keyword (models): Dupla Livre de Pelos Encravados
#  [98/146] https://www.sallve.com.br/products/dupla-cuidado-corporal
#
# Excluído por keyword (models): Dupla Cuidado Corporal
#  [99/146] https://www.sallve.com.br/products/hidratante-renovador-corporal
#
# Excluído por keyword (models): Dupla Cuidado Corporal
#  [99/146] https://www.sallve.com.br/products/hidratante-renovador-corporal
#
# Excluído por keyword (models): Hidratante Renovador Corporal
#  [100/146] https://www.sallve.com.br/products/protetor-solar-corporal-fps50
#
# Excluído por keyword (models): Hidratante Renovador Corporal
#  [100/146] https://www.sallve.com.br/products/protetor-solar-corporal-fps50
#
# Excluído por keyword (models): Protetor Solar Corporal FPS 50
#  [101/146] https://www.sallve.com.br/products/refil-limpador-facial
#
# Excluído por keyword (models): Protetor Solar Corporal FPS 50
#  [101/146] https://www.sallve.com.br/products/refil-limpador-facial
#
# Excluído por keyword (models): Refil Limpador Facial
#  [102/146] https://www.sallve.com.br/products/refil-limpador-antioleosidade
#
# Excluído por keyword (models): Refil Limpador Facial
#  [102/146] https://www.sallve.com.br/products/refil-limpador-antioleosidade
#
# Excluído por keyword (models): Refil Limpador Antioleosidade
#  [103/146] https://www.sallve.com.br/products/refil-limpador-antiacne
#
# Excluído por keyword (models): Refil Limpador Antioleosidade
#  [103/146] https://www.sallve.com.br/products/refil-limpador-antiacne
#
# Excluído por keyword (models): Refil Limpador Antiacne
#  [104/146] https://www.sallve.com.br/products/kit-2-unidades-refil-limpador-facial
#
# Excluído por keyword (models): Refil Limpador Antiacne
#  [104/146] https://www.sallve.com.br/products/kit-2-unidades-refil-limpador-facial
#
# Excluído por keyword (models): Kit 2 unidades Refil Limpador Facial
#  [105/146] https://www.sallve.com.br/products/dupla-vitamina-c-hialuronico-retinol-biomimetico
#
# Excluído por keyword (models): Kit 2 unidades Refil Limpador Facial
#  [105/146] https://www.sallve.com.br/products/dupla-vitamina-c-hialuronico-retinol-biomimetico
#
# Excluído por keyword (models): Dupla Vitamina C + Hialurônico + Retinol Biomimético
#  [106/146] https://www.sallve.com.br/products/kit-controle-de-poros
#
# Excluído por keyword (models): Dupla Vitamina C + Hialurônico + Retinol Biomimético
#  [106/146] https://www.sallve.com.br/products/kit-controle-de-poros
#
# Excluído por keyword (models): kit controle de poros
#  [107/146] https://www.sallve.com.br/products/dupla-essencial
#
# Excluído por keyword (models): kit controle de poros
#  [107/146] https://www.sallve.com.br/products/dupla-essencial
#
# Excluído por keyword (models): Dupla Essencial
#  [108/146] https://www.sallve.com.br/products/dupla-antiacne-e-antioleosidade
#
# Excluído por keyword (models): Dupla Essencial
#  [108/146] https://www.sallve.com.br/products/dupla-antiacne-e-antioleosidade
#
# Excluído por keyword (models): Dupla Antiacne e Antioleosidade
#  [109/146] https://www.sallve.com.br/products/dupla-antiatrito-e-antioleosidade
#
# Excluído por keyword (models): Dupla Antiacne e Antioleosidade
#  [109/146] https://www.sallve.com.br/products/dupla-antiatrito-e-antioleosidade
#
# Excluído por keyword (models): Dupla Antiatrito e Antioleosidade
#  [110/146] https://www.sallve.com.br/products/dupla-antioleosidade
#
# Excluído por keyword (models): Dupla Antiatrito e Antioleosidade
#  [110/146] https://www.sallve.com.br/products/dupla-antioleosidade
#
# Excluído por keyword (models): Dupla Antioleosidade
#  [111/146] https://www.sallve.com.br/products/trio-pele-sequinha
#
# Excluído por keyword (models): Dupla Antioleosidade
#  [111/146] https://www.sallve.com.br/products/trio-pele-sequinha
#
# Excluído por keyword (models): trio pele sequinha
#  [112/146] https://www.sallve.com.br/products/trio-essencial-pele-oleosa
#
# Excluído por keyword (models): trio pele sequinha
#  [112/146] https://www.sallve.com.br/products/trio-essencial-pele-oleosa
#
# Excluído por keyword (models): trio essencial - pele oleosa
#  [113/146] https://www.sallve.com.br/products/dupla-livre-de-oleosidade
#
# Excluído por keyword (models): trio essencial - pele oleosa
#  [113/146] https://www.sallve.com.br/products/dupla-livre-de-oleosidade
#
# Excluído por keyword (models): dupla livre de oleosidade
#  [114/146] https://www.sallve.com.br/products/dupla-super-antioleosidade
#
# Excluído por keyword (models): dupla livre de oleosidade
#  [114/146] https://www.sallve.com.br/products/dupla-super-antioleosidade
#
# Excluído por keyword (models): dupla super antioleosidade
#  [115/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-antioleosidade
#
# Excluído por keyword (models): dupla super antioleosidade
#  [115/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-antioleosidade
#
# Excluído por keyword (models): Dupla Antiolheiras e Antioleosidade
#  [116/146] https://www.sallve.com.br/products/dupla-anti-cravo-dia-e-noite
#
# Excluído por keyword (models): Dupla Antiolheiras e Antioleosidade
#  [116/146] https://www.sallve.com.br/products/dupla-anti-cravo-dia-e-noite
#
# Excluído por keyword (models): Dupla Anti Cravo Dia e Noite
#  [117/146] https://www.sallve.com.br/products/kit-anticravo-gentil
#
# Excluído por keyword (models): Dupla Anti Cravo Dia e Noite
#  [117/146] https://www.sallve.com.br/products/kit-anticravo-gentil
#
# Excluído por keyword (models): Kit Anticravo Gentil
#  [118/146] https://www.sallve.com.br/products/dupla-anti-cravo
#
# Excluído por keyword (models): Kit Anticravo Gentil
#  [118/146] https://www.sallve.com.br/products/dupla-anti-cravo
#
# Excluído por keyword (models): Dupla anti cravo
#  [119/146] https://www.sallve.com.br/products/dupla-efeito-imediato
#
# Excluído por keyword (models): Dupla anti cravo
#  [119/146] https://www.sallve.com.br/products/dupla-efeito-imediato
#
# Excluído por keyword (models): Dupla Efeito Imediato
#  [120/146] https://www.sallve.com.br/products/dupla-renovacao-dia-e-noite
#
# Excluído por keyword (models): Dupla Efeito Imediato
#  [120/146] https://www.sallve.com.br/products/dupla-renovacao-dia-e-noite
#
# Excluído por keyword (models): Dupla Renovação Dia e Noite
#  [121/146] https://www.sallve.com.br/products/dupla-antiolheiras-dia-e-noite
#
# Excluído por keyword (models): Dupla Renovação Dia e Noite
#  [121/146] https://www.sallve.com.br/products/dupla-antiolheiras-dia-e-noite
#
# Excluído por keyword (models): Dupla Antiolheiras Dia e Noite
#  [122/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-protecao-antimanchas
#
# Excluído por keyword (models): Dupla Antiolheiras Dia e Noite
#  [122/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-protecao-antimanchas
#
# Excluído por keyword (models): Dupla Antiolheiras e Proteção Antimanchas
#  [123/146] https://www.sallve.com.br/products/dupla-olhar-radiante
#
# Excluído por keyword (models): Dupla Antiolheiras e Proteção Antimanchas
#  [123/146] https://www.sallve.com.br/products/dupla-olhar-radiante
#
# Excluído por keyword (models): Dupla Olhar Radiante
#  [124/146] https://www.sallve.com.br/products/dupla-menos-olheiras-mais-firmeza
#
# Excluído por keyword (models): Dupla Olhar Radiante
#  [124/146] https://www.sallve.com.br/products/dupla-menos-olheiras-mais-firmeza
#
# Excluído por keyword (models): Dupla Menos Olheiras, Mais Firmeza
#  [125/146] https://www.sallve.com.br/products/dupla-menos-olheiras-mais-vico
#
# Excluído por keyword (models): Dupla Menos Olheiras, Mais Firmeza
#  [125/146] https://www.sallve.com.br/products/dupla-menos-olheiras-mais-vico
#
# Excluído por keyword (models): Dupla Menos Olheiras, Mais Viço
#  [126/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-protecao-sequinha
#
# Excluído por keyword (models): Dupla Menos Olheiras, Mais Viço
#  [126/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-protecao-sequinha
#
# Excluído por keyword (models): Dupla Antiolheiras e Proteção Sequinha
#  [127/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-antimarcas
#
# Excluído por keyword (models): Dupla Antiolheiras e Proteção Sequinha
#  [127/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-antimarcas
#
# Excluído por keyword (models): Dupla Antiolheiras e Antimarcas
#  [128/146] https://www.sallve.com.br/products/dupla-uniformizadora
#
# Excluído por keyword (models): Dupla Antiolheiras e Antimarcas
#  [128/146] https://www.sallve.com.br/products/dupla-uniformizadora
#
# Excluído por keyword (models): Dupla Uniformizadora
#  [129/146] https://www.sallve.com.br/products/dupla-livre-de-olheiras-e-oleosidade
#
# Excluído por keyword (models): Dupla Uniformizadora
#  [129/146] https://www.sallve.com.br/products/dupla-livre-de-olheiras-e-oleosidade
#
# Excluído por keyword (models): Dupla Livre de Olheiras e Oleosidade
#  [130/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-anticravos
#
# Excluído por keyword (models): Dupla Livre de Olheiras e Oleosidade
#  [130/146] https://www.sallve.com.br/products/dupla-antiolheiras-e-anticravos
#
# Excluído por keyword (models): Dupla Antiolheiras e Anticravos
#  [131/146] https://www.sallve.com.br/products/protetor-solar-com-cor-fps-60
#
# Excluído por keyword (models): Dupla Antiolheiras e Anticravos
#  [131/146] https://www.sallve.com.br/products/protetor-solar-com-cor-fps-60
#
# OK: Protetor Solar com Cor Toque Seco FPS 60
#
# OK: Protetor Solar com Cor Toque Seco FPS 60
#  [132/146] https://www.sallve.com.br/products/kit-rotina-completa-antiacne
#  [132/146] https://www.sallve.com.br/products/kit-rotina-completa-antiacne
#
# Excluído por keyword (models): Kit Rotina Completa Antiacne
#  [133/146] https://www.sallve.com.br/products/dupla-antiacne-rosto-e-corpo
#
# Excluído por keyword (models): Kit Rotina Completa Antiacne
#  [133/146] https://www.sallve.com.br/products/dupla-antiacne-rosto-e-corpo
#
# Excluído por keyword (models): Dupla Antiacne Rosto e Corpo
#  [134/146] https://www.sallve.com.br/products/spray-corporal-antiacne
#
# Excluído por keyword (models): Dupla Antiacne Rosto e Corpo
#  [134/146] https://www.sallve.com.br/products/spray-corporal-antiacne
#
# Excluído por keyword (models): Spray Antiacne Corporal
#  [135/146] https://www.sallve.com.br/products/protetor-solar-fps60
#
# Excluído por keyword (models): Spray Antiacne Corporal
#  [135/146] https://www.sallve.com.br/products/protetor-solar-fps60
#
# OK: Protetor Solar FPS 60
#
# OK: Protetor Solar FPS 60
#  [136/146] https://www.sallve.com.br/products/oleo-antissinais
#  [136/146] https://www.sallve.com.br/products/oleo-antissinais
#
# OK: Óleo Antissinais
#
# OK: Óleo Antissinais
#  [137/146] https://www.sallve.com.br/products/hidratante-corporal-antioxidante
#  [137/146] https://www.sallve.com.br/products/hidratante-corporal-antioxidante
#
# Excluído por keyword (models): Hidratante Corporal Antioxidante
#  [138/146] https://www.sallve.com.br/products/oleo-facial-antioxidante
#
# Excluído por keyword (models): Hidratante Corporal Antioxidante
#  [138/146] https://www.sallve.com.br/products/oleo-facial-antioxidante
#
# OK: Óleo Facial Antioxidante
#
# OK: Óleo Facial Antioxidante
#  [139/146] https://www.sallve.com.br/products/vitamina-c-fps-30-antioxidante-hidratante
#  [139/146] https://www.sallve.com.br/products/vitamina-c-fps-30-antioxidante-hidratante
#
# OK: Vitamina C FPS 30 Antioxidante Hidratante
#
# OK: Vitamina C FPS 30 Antioxidante Hidratante
#  [140/146] https://www.sallve.com.br/products/mascara-antirressaca
#  [140/146] https://www.sallve.com.br/products/mascara-antirressaca
#
# OK: Máscara Antirressaca
#
# OK: Máscara Antirressaca
#  [141/146] https://www.sallve.com.br/products/oleo-corporal-antioxidante
#  [141/146] https://www.sallve.com.br/products/oleo-corporal-antioxidante
#
# Excluído por keyword (models): Óleo Corporal Antioxidante
#  [142/146] https://www.sallve.com.br/products/vitamina-c-antioxidante-hidratante-pele-sensivel
#
# Excluído por keyword (models): Óleo Corporal Antioxidante
#  [142/146] https://www.sallve.com.br/products/vitamina-c-antioxidante-hidratante-pele-sensivel
#
# OK: Vitamina C Antioxidante Hidratante Pele Sensível
#
# OK: Vitamina C Antioxidante Hidratante Pele Sensível
#  [143/146] https://www.sallve.com.br/products/dupla-cuidado-diario-pele-sensivel
#  [143/146] https://www.sallve.com.br/products/dupla-cuidado-diario-pele-sensivel
#
# Excluído por keyword (models): Dupla Cuidado Diário - Pele Sensível
#  [144/146] https://www.sallve.com.br/products/kit-rotina-renovacao
#
# Excluído por keyword (models): Dupla Cuidado Diário - Pele Sensível
#  [144/146] https://www.sallve.com.br/products/kit-rotina-renovacao
#
# Excluído por keyword (models): Kit Rotina Renovação
#  [145/146] https://www.sallve.com.br/products/kit-rotina-anticravo
#
# Excluído por keyword (models): Kit Rotina Renovação
#  [145/146] https://www.sallve.com.br/products/kit-rotina-anticravo
#
# Excluído por keyword (models): Kit Rotina Anticravo
#  [146/146] https://www.sallve.com.br/products/dupla-queridinhos-da-rede-vizinha-com-cor
#
# Excluído por keyword (models): Kit Rotina Anticravo
#  [146/146] https://www.sallve.com.br/products/dupla-queridinhos-da-rede-vizinha-com-cor
#
# Excluído por keyword (models): Dupla Queridinhos da Rede Vizinha - com cor
# Total pós-filtro: 42
#
# Coletando tipos de pele via filtros da Sallve...
#  - Filtro 'todos os tipos': https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=todos+os+tipos+de+pele
#
# Excluído por keyword (models): Dupla Queridinhos da Rede Vizinha - com cor
# Total pós-filtro: 42
#
# Coletando tipos de pele via filtros da Sallve...
#  - Filtro 'todos os tipos': https://www.sallve.com.br/collections/super-ativos?filter.p.m.filter.skin_type=todos+os+tipos+de+pele
#    · 13 nome(s) coletado(s)
#    · 13 nome(s) coletado(s)
# JSON: sallve_products.json (42 produtos)
# ____________________________________________________________________________________________________________
#
# Fim da execução! Produtos extraídos: 42
# Imagens salvas em: /home/usuario/Área de trabalho/Dados/Sallve/images
# ____________________________________________________________________________________________________________
# JSON: sallve_products.json (42 produtos)
# ____________________________________________________________________________________________________________
#
# Fim da execução! Produtos extraídos: 42
# Imagens salvas em: /home/usuario/Área de trabalho/Dados/Sallve/images
# ____________________________________________________________________________________________________________

# %% [markdown]
# ## Conversão JSON para CSV

# %%
def json_to_csv(json_file="sallve_products.json", csv_file="sallve_products.csv"):

    try:
        with open(json_file, "r", encoding="utf-8") as f:
            data = json.load(f)
        
        if not data:
            print(f"Nenhum dado encontrado no arquivo {json_file}")
            return
        
        cols = ["marca", "nome", "subtitulo", "categoria", "quantidade", "preco", "beneficios", "ingredientes", "tipo_pele", "imagem"]
        
        with open(csv_file, "w", encoding="utf-8", newline="") as f:
            writer = csv.DictWriter(f, fieldnames=cols)
            writer.writeheader()
            for row in data:

                csv_row = {k: (row.get(k) or "") for k in cols}
                writer.writerow(csv_row)
        
        print(f"CSV gerado: {csv_file} ({len(data)} linhas)")
        print(f"A partir do JSON: {json_file}")
        
    except FileNotFoundError:
        print(f" Arquivo {json_file} não encontrado!")
        
        import glob
        json_files = glob.glob("*.json")
        if json_files:
            for f in json_files:
                print(f"   - {f}")
        else:
            print("   Nenhum arquivo .json encontrado")
    except Exception as e:
        print(f"Erro ao converter JSON para CSV: {e}")


json_to_csv("sallve_products.json")
# Out:
# CSV gerado: sallve_products.csv (39 linhas)
# A partir do JSON: sallve_products.json
