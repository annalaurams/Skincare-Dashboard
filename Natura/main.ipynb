# %%
# -*- coding: utf-8 -*-
import sys, os, re, json, time, unicodedata
from pathlib import Path
from typing import List, Dict, Optional
from urllib.parse import urljoin, urlparse

import requests
import pandas as pd
from bs4 import BeautifulSoup

# ===== Ajuste o sys.path para sua pasta "models" =====
sys.path.append(os.path.abspath("/home/usuario/Área de trabalho/Dados/models"))

from skin import SKIN_TYPE_CANONICAL_ORDER, SKIN_TYPE_SYNONYMS_PT
from exclude import EXCLUDE_KEYWORDS
from ingredient import INGREDIENTES_VALIDOS
from benefits import BENEFIT_SYNONYMS_PT, BENEFIT_CANONICAL_ORDER
from category import CATEGORY_CANONICAL_ORDER, CATEGORY_HINTS

# -------------------- Config --------------------
BASE_URL = "https://www.natura.com.br"

# Salvar diretamente na raiz do projeto
JSON_PATH = Path("natura_products.json")
CSV_PATH  = Path("natura_products.csv")

# Pasta de imagens (fora de outputs/)
IMG_DIR = Path("./images/natura")
IMG_DIR.mkdir(parents=True, exist_ok=True)

SESSION = requests.Session()
SESSION.headers.update({
    "User-Agent": "Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/124 Safari/537.36",
    "Accept-Language": "pt-BR,pt;q=0.9,en;q=0.8",
})

NBSP = "\xa0"
CURRENCY_RE = re.compile(r"R\$\s*([\d\.]+,\d{2})")
QTY_RE = re.compile(r"(\d+(?:[.,]\d+)?)\s*(ml|g|l|kg|un|unid|unidades)\b", re.I)

# -------------------- Helpers básicos --------------------
def _strip(s: str) -> str:
    return re.sub(r"\s+", " ", s or "").strip()

def _norm(s: str) -> str:
    s = (s or "").replace(NBSP, " ")
    s = unicodedata.normalize("NFKD", s)
    s = "".join(c for c in s if not unicodedata.combining(c))
    s = re.sub(r"[\s_/,-]+", " ", s)  # normaliza separadores
    return s.strip().lower()

def sanitize_filename(s: str) -> str:
    s = _norm(s)
    s = re.sub(r"[^a-z0-9\._-]+", "-", s)
    s = re.sub(r"-{2,}", "-", s).strip("-")
    return s or "img"

def br_money_to_float_str(text: str) -> Optional[str]:
    if not text:
        return None
    m = CURRENCY_RE.search(text)
    if not m:
        return None
    raw = m.group(1).replace(".", "").replace(",", ".")
    try:
        return f"{float(raw):.2f}"
    except ValueError:
        return None

def extract_quantity(text: str) -> Optional[str]:
    if not text:
        return None
    m = QTY_RE.search(text)
    if not m:
        return None
    val = m.group(1).replace(",", ".")
    unit = m.group(2).lower()
    unit = {"unid": "un", "unidades": "un"}.get(unit, unit)
    return f"{val}{unit}" if unit in {"ml","g","l","kg"} else f"{val} {unit}"

def should_exclude(name: str) -> bool:
    n = _norm(name)
    for kw in list(EXCLUDE_KEYWORDS) + ["kit", "refil", "refill", "combo", "duo", "trio", "necessaire", "presente", "gift"]:
        if _norm(kw) in n:
            return True
    return False

# -------------------- Coleta de URLs via sitemap --------------------
def get_sitemap_product_urls() -> List[str]:
    r = SESSION.get(urljoin(BASE_URL, "/robots.txt"), timeout=20)
    r.raise_for_status()
    m = re.search(r"Sitemap:\s*(\S+Feed-SiteMap)", r.text)
    if not m:
        return []
    sitemap_url = m.group(1)
    r2 = SESSION.get(sitemap_url, timeout=40)
    r2.raise_for_status()
    soup = BeautifulSoup(r2.text, "xml")
    urls = sorted({loc.get_text(strip=True) for loc in soup.find_all("loc") if "/p/" in loc.get_text()})

    # filtra candidatos de skincare por slug para reduzir chamadas
    SKIN_SLUGS = ("chronos", "derma", "rosto", "protetor", "serum", "sérum",
                  "hidratante-facial", "creme-antissinais", "sabonete-facial",
                  "agua-micelar", "máscara", "mascara", "clareador", "antissinais", "antioxidante")
    urls = [u for u in urls if any(s in u.lower() for s in SKIN_SLUGS)]
    return urls

def get_soup(url: str) -> Optional[BeautifulSoup]:
    for i in range(3):
        try:
            resp = SESSION.get(url, timeout=30)
            if resp.status_code == 200:
                return BeautifulSoup(resp.text, "lxml")
        except requests.RequestException:
            pass
        time.sleep(1 + i)
    return None

# -------------------- Extração por produto --------------------
def extract_name_subtitle_qty(soup: BeautifulSoup) -> (str, Optional[str], Optional[str]):
    name = ""
    h1 = soup.find("h1")
    if h1:
        name = _strip(h1.get_text())
    subtitle = None
    for p in soup.select("p.text-xs, p.text-low-emphasis, p"):
        txt = _strip(p.get_text())
        if len(txt) >= 6 and (" ml" in f" {txt.lower()} " or " g" in f" {txt.lower()} "):
            subtitle = txt
            break
    qty = extract_quantity(subtitle or "")
    return name, subtitle, qty

def extract_price_str(soup: BeautifulSoup) -> Optional[str]:
    prices = set()
    for el in soup.select("span, div, p"):
        val = br_money_to_float_str(el.get_text(" ", strip=True))
        if val:
            prices.add(val)
    if not prices:
        return None
    return f"{min(prices, key=lambda x: float(x))}"

# ---------- BENEFÍCIOS ----------
def map_benefits(raw_texts: List[str]) -> List[str]:
    found = set()
    joined = " " + " ; ".join(_norm(t) for t in raw_texts) + " "
    for canonical in BENEFIT_CANONICAL_ORDER:
        syns = BENEFIT_SYNONYMS_PT.get(canonical, [])
        # casa contra sinônimos e o próprio canônico
        if any(re.search(rf"\b{re.escape(_norm(s))}\b", joined) for s in syns + [canonical]):
            found.add(canonical)
    ordered = [b for b in BENEFIT_CANONICAL_ORDER if b in found]
    return ordered

def extract_product_tags_and_benefits(soup: BeautifulSoup) -> (List[str], List[str]):
    tags = []
    ben_raw = []

    cont = soup.find(attrs={"data-testid": "product-tags"})
    if cont:
        # 1) data-gtm-product-tags (ex.: "chronos derma|creme antissinais|todos os tipos de pele|antissinais")
        d = cont.get("data-gtm-product-tags")
        if d:
            tags.extend([_strip(x) for x in d.split("|") if _strip(x)])

        # 2) texto dos botões
        for btn in cont.find_all("button"):
            spans = btn.select("span[aria-hidden='true']")
            t = _strip(spans[-1].get_text()) if spans else _strip(btn.get_text())
            if t:
                tags.append(t)

    # 3) “Resultados comprovados”: bullets como benefícios
    # localizar o botão com texto "resultados comprovados"
    btns = soup.find_all("button")
    for b in btns:
        label = _strip(b.get_text())
        if _norm(label) == "resultados comprovados":
            # varre irmãos seguintes em busca de <p> bullets (•)
            sib = b.find_next_sibling()
            steps = 0
            while sib and steps < 12:
                for p in sib.select("p"):
                    txt = _strip(p.get_text(" ", strip=True))
                    if re.match(r"^[•\-\u2022]\s*", txt):
                        txt = re.sub(r"^[•\-\u2022]\s*", "", txt).strip()
                        if 3 <= len(txt) <= 240:
                            ben_raw.append(txt)
                sib = sib.find_next_sibling()
                steps += 1
            break

    # dedup preservando ordem
    tags = list(dict.fromkeys(tags))
    benefits = map_benefits(ben_raw + tags)  # tags também podem carregar benefícios (ex.: "antissinais")
    return tags, benefits

# ---------- TIPOS DE PELE (somente via tags) ----------
def map_skin_types_from_tags(tags: List[str]) -> List[str]:
    out = set()
    joined = " " + " ; ".join(_norm(t) for t in tags) + " "
    for canonical, syns in SKIN_TYPE_SYNONYMS_PT.items():
        if any(re.search(rf"\b{re.escape(_norm(s))}\b", joined) for s in syns + [canonical]):
            out.add(canonical)
    ordered = [s for s in SKIN_TYPE_CANONICAL_ORDER if s in out]
    return ordered or ["todos os tipos"]

# ---------- INGREDIENTES (filtrando contra INGREDIENTES_VALIDOS) ----------
def extract_ingredients_text(soup: BeautifulSoup) -> str:
    # Procura o botão "ingredientes" e lê o conteúdo seguinte
    for btn in soup.find_all("button"):
        label = _strip(btn.get_text())
        if _norm(label) == "ingredientes":
            # Na Natura, o bloco aberto aparece logo após o botão
            # Buscamos spans/p/divs com o texto, priorizando <span class="text-sm">
            collected = []
            sib = btn.find_next_sibling()
            steps = 0
            while sib and steps < 12:
                spans = sib.select("span.text-sm")
                if spans:
                    for s in spans:
                        t = _strip(s.get_text(" ", strip=True))
                        if len(t) > 10:
                            collected.append(t)
                else:
                    # fallback: pega texto do irmão se for grande
                    t = _strip(sib.get_text(" ", strip=True))
                    if t.count(",") >= 6 or "/" in t:
                        collected.append(t)
                sib = sib.find_next_sibling()
                steps += 1
            if collected:
                # escolha o maior bloco
                collected.sort(key=len, reverse=True)
                return collected[0]
    # Fallback: maior bloco químico na página
    candidate = ""
    for el in soup.select("span, p, div"):
        tt = _strip(el.get_text(" ", strip=True))
        if tt.count(",") >= 6 or "/" in tt:
            if len(tt) > len(candidate):
                candidate = tt
    return candidate

def tokenize_and_filter_ingredients(raw_text: str) -> List[str]:
    if not raw_text:
        return []
    # Split por vírgula e por barra (ex.: "AQUA/ WATER/ EAU")
    parts = []
    for chunk in re.split(r",", raw_text):
        parts.extend(re.split(r"/", chunk))
    # normaliza a lista válida uma vez
    valid_norm_map = {_norm(v): v for v in INGREDIENTES_VALIDOS}

    out = []
    seen = set()
    for p in parts:
        tok = _strip(p).strip().strip(".")
        if not tok:
            continue
        key = _norm(tok)
        # regra de match: igualdade exata por normalização OU
        # o válido contido no token (para casos com sufixos) OU token contido no válido (casos compactos)
        matched = None
        if key in valid_norm_map:
            matched = valid_norm_map[key]
        else:
            for k_valid, v_canon in valid_norm_map.items():
                if k_valid and (k_valid in key or key in k_valid) and len(k_valid) >= 4:
                    matched = v_canon
                    break
        if matched:
            k2 = _norm(matched)
            if k2 not in seen:
                seen.add(k2)
                out.append(matched)
    return out

# ---------- Categoria ----------
def classify_category(name: str, subtitle: Optional[str]) -> Optional[str]:
    base = f"{name} {subtitle or ''}"
    text = _norm(base)
    hits = []
    for cat, hints in CATEGORY_HINTS.items():
        if any(_norm(h) in text for h in hints):
            hits.append(cat)
    if not hits:
        return None
    for cat in CATEGORY_CANONICAL_ORDER:
        if cat in hits:
            return cat
    return hits[0]

# ---------- Imagem (prioriza '/Produtos/') ----------
def extract_product_image_url(soup: BeautifulSoup) -> Optional[str]:
    def _split_srcset(s: str) -> List[str]:
        return [p.strip().split(" ")[0] for p in (s or "").split(",") if p.strip()]

    blacklist = ("logo", "icone", "icon", "sprite", "favicon", "/icons/")
    def _bad(u: str) -> bool:
        u_low = u.lower()
        return any(b in u_low for b in blacklist)

    candidates: List[str] = []

    # 1) picture/source com srcset contendo '/Produtos/'
    for src in soup.select("picture source[srcset]"):
        for url in _split_srcset(src.get("srcset", "")):
            if "/Produtos/" in url and not _bad(url):
                candidates.append(url)

    # 2) imgs do “gallery”/“product-image” e correlatos
    for img in soup.select(
        "[data-testid='product-tags'] ~ * img, "
        "[data-testid*='product'] img, "
        "[class*='gallery'] img, "
        "img[pictureclassname], img.object-cover, img.object-contain, img"
    ):
        url = img.get("src") or img.get("data-src") or img.get("data-zoom-src") or ""
        if not url:
            for url2 in _split_srcset(img.get("srcset", "")):
                if "/Produtos/" in url2 and not _bad(url2):
                    candidates.append(url2)
            continue
        if "/Produtos/" in url and not _bad(url):
            candidates.append(url)

    # ranking
    def score(u: str) -> tuple:
        path = urlparse(u).path.lower()
        return (1 if "natbra-" in path else 0, 1 if "/Produtos/" in path else 0, len(path))

    candidates = sorted(set(candidates), key=score, reverse=True)
    return candidates[0] if candidates else None

def download_image(img_url: str, product_name: str) -> Optional[str]:
    if not img_url:
        return None
    if img_url.startswith("//"):
        img_url = "https:" + img_url
    elif img_url.startswith("/"):
        img_url = urljoin(BASE_URL, img_url)

    ext = os.path.splitext(urlparse(img_url).path)[1].lower()
    if ext not in (".jpg", ".jpeg", ".png", ".webp"):
        ext = ".jpg"

    fname = sanitize_filename(product_name) + ext
    fpath = IMG_DIR / fname
    try:
        r = SESSION.get(img_url, timeout=30)
        if r.status_code == 200:
            ctype = (r.headers.get("Content-Type") or "").lower()
            if not ctype.startswith("image"):
                return None
            if len(r.content) < 15000:  # evita logos pequenas
                return None
            with open(fpath, "wb") as f:
                f.write(r.content)
            return fname  # apenas o filename
    except requests.RequestException:
        return None
    return None

# ---------- Parse do produto completo ----------
def parse_product(url: str) -> Optional[Dict]:
    soup = get_soup(url)
    if not soup:
        return None

    name, subtitle, qty = extract_name_subtitle_qty(soup)
    if not name or should_exclude(name):
        return None

    price = extract_price_str(soup)  # "99.90" (string)

    # tags (para pele e possíveis benefícios)
    tags, benefits_from_tags = extract_product_tags_and_benefits(soup)
    # tipos de pele: SOMENTE pelos tags
    skin_types = map_skin_types_from_tags(tags)

    # ingredientes: via botão "ingredientes"
    ing_text = extract_ingredients_text(soup)
    ingredients = tokenize_and_filter_ingredients(ing_text)

    # benefícios finais (tags + bullets “resultados comprovados” já mapeados)
    benefits = benefits_from_tags

    category = classify_category(name, subtitle)

    # imagem
    img_src = extract_product_image_url(soup)
    img_filename = download_image(img_src, name)

    # === Formato EXATO pedido ===
    item = {
        "marca": "natura",
        "nome": name,
        "subtitulo": subtitle if subtitle else None,
        "categoria": category,
        "quantidade": qty,
        "preco": price,  # string "99.90"
        "beneficios": "; ".join(benefits) if benefits else None,
        "ingredientes": "; ".join(ingredients) if ingredients else None,
        "tipo_pele": "; ".join(skin_types) if skin_types else None,
        "imagem": img_filename,  # apenas o filename
    }
    return item

# -------------------- Main --------------------
def main():
    print("[Natura/Rosto] Coletando URLs pelo sitemap…")
    urls = get_sitemap_product_urls()
    print(f"URLs candidatadas: {len(urls)}")

    results = []
    seen = set()
    for i, url in enumerate(urls, 1):
        try:
            it = parse_product(url)
            if not it:
                status = "descartado"
            else:
                key = _norm(it["nome"])
                if key in seen:
                    status = "duplicado"
                else:
                    seen.add(key)
                    results.append(it)
                    status = "ok"
        except Exception as e:
            status = f"erro:{e.__class__.__name__}"
        print(f"[{i}/{len(urls)}] {status} - {url}")
        time.sleep(0.25)

    # salva JSON e CSV na raiz, com os nomes pedidos
    with open(JSON_PATH, "w", encoding="utf-8") as f:
        json.dump(results, f, ensure_ascii=False, indent=2)

    df = pd.DataFrame(results)
    df.to_csv(CSV_PATH, index=False, encoding="utf-8-sig")

    print(f"Salvo JSON: {JSON_PATH}")
    print(f"Salvo CSV : {CSV_PATH}")
    print(f"Itens válidos: {len(results)}")

if __name__ == "__main__":
    main()
# Out:
# /home/usuario/.local/lib/python3.12/site-packages/pandas/core/arrays/masked.py:61: UserWarning: Pandas requires version '1.3.6' or newer of 'bottleneck' (version '1.3.5' currently installed).
#   from pandas.core import (
# [Natura/Rosto] Coletando URLs pelo sitemap…
# URLs candidatadas: 276
# [1/276] ok - https://www.natura.com.br/p/agua-micelar-demaquilante-suave-chronos-derma-150-ml/NATBRA-133503
# [2/276] ok - https://www.natura.com.br/p/balm-redutor-de-rugas-chronos-derma-15-g/NATBRA-169217
# [3/276] ok - https://www.natura.com.br/p/balm-redutor-de-rugas-para-olhos-chronos-15-g/NATBRA-111332
# [4/276] ok - https://www.natura.com.br/p/base-serum-nude-me-una-30ml/NATBRA-PAI110201
# [5/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110181
# [6/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110182
# [7/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110183
# [8/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110184
# [9/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110185
# [10/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110186
# [11/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110187
# [12/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110188
# [13/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110189
# [14/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110190
# [15/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110191
# [16/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110192
# [17/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110193
# [18/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110194
# [19/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110195
# [20/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110196
# [21/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110197
# [22/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110198
# [23/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110199
# [24/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110200
# [25/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110201
# [26/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110202
# [27/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110203
# [28/276] duplicado - https://www.natura.com.br/p/base-serum-nude-me-una/NATBRA-110204
# [29/276] ok - https://www.natura.com.br/p/bruma-spray-hidratante-facial-faces-100-ml/NATBRA-113704
# [30/276] ok - https://www.natura.com.br/p/chronos-antisssinais-renovacao-e-energia-30+-noite-15g/NATBRA-102710
# [31/276] descartado - https://www.natura.com.br/p/condicionador-protetor-hidratacao-e-protecao-antipoluicao-lumina-300-ml/NATBRA-147446
# [32/276] descartado - https://www.natura.com.br/p/condicionador-protetor-para-cabelos-lisos-lumina-300-ml/NATBRA-86968
# [33/276] descartado - https://www.natura.com.br/p/condicionador-protetor-para-cabelos-opacos-ou-com-coloracao-lumina-300-ml/NATBRA-148433
# [34/276] ok - https://www.natura.com.br/p/creme-antissinais-70+-dia-defesa-e-restauracao-chronos-40-g/NATBRA-57994
# [35/276] ok - https://www.natura.com.br/p/creme-antissinais-70+-noite-defesa-e-restauracao-chronos-40-g/NATBRA-57999
# [36/276] ok - https://www.natura.com.br/p/creme-antissinais-fortalecimento-e-nutricao-80+-dia-chronos-derma-40-g/NATBRA-134695
# [37/276] ok - https://www.natura.com.br/p/creme-antissinais-fortalecimento-e-nutricao-80+-noite-chronos-derma-40-g/NATBRA-135039
# [38/276] ok - https://www.natura.com.br/p/creme-antissinais-preenchimento-e-revitalizacao-60+-dia-chronos-40-g/NATBRA-57985
# [39/276] ok - https://www.natura.com.br/p/creme-antissinais-preenchimento-e-revitalizacao-60+-dia-chronos-derma-40-g/NATBRA-134693
# [40/276] ok - https://www.natura.com.br/p/creme-antissinais-preenchimento-e-revitalizacao-60+-noite-chronos-derma-40-g/NATBRA-135036
# [41/276] ok - https://www.natura.com.br/p/creme-antissinais-restauracao-e-cuidado-70+-dia-chronos-derma-40-g/NATBRA-134697
# [42/276] ok - https://www.natura.com.br/p/creme-antissinais-restauracao-e-cuidado-70+-noite-chronos-derma-40-g/NATBRA-135027
# [43/276] ok - https://www.natura.com.br/p/demaquilante-bifasico-chronos-150-ml/NATBRA-61263
# [44/276] ok - https://www.natura.com.br/p/espuma-limpeza-suave-chronos-150-ml/NATBRA-59363
# [45/276] ok - https://www.natura.com.br/p/essencia-de-tratamento-revitalizacao-e-luminosidade-chronos-derma-100-ml/NATBRA-135043
# [46/276] duplicado - https://www.natura.com.br/p/fluido-bifasico-demaquilante-intensivo-chronos-derma-150-ml/NATBRA-137976
# [47/276] ok - https://www.natura.com.br/p/fluido-multiprotetor-fps-50-fpuva-18-chronos-50-ml/NATBRA-68542
# [48/276] ok - https://www.natura.com.br/p/gel-booster-hidratante-facial-faces-35-g/NATBRA-118910
# [49/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-30+-dia-renovacao-e-energia-chronos-40-g/NATBRA-57996
# [50/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-45+-dia-firmeza-e-radiancia-chronos-40-g/NATBRA-58006
# [51/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-45+-noite-firmeza-e-radiancia-chronos-40-g/NATBRA-58002
# [52/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-firmeza-e-luminosidade-45+-dia-chronos-derma-40-g/NATBRA-134725
# [53/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-firmeza-e-luminosidade-45+-noite-chronos-derma-40-g/NATBRA-135032
# [54/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-renovacao-e-prevencao-30+-dia-chronos-derma-40-g/NATBRA-134592
# [55/276] ok - https://www.natura.com.br/p/gel-creme-antissinais-renovacao-e-prevencao-30+-noite-chronos-derma-40-g/NATBRA-134593
# [56/276] ok - https://www.natura.com.br/p/hidratante-acqua-renovador-chronos-derma-40-g/NATBRA-91849
# [57/276] ok - https://www.natura.com.br/p/hidratante-facial-intensivo-faces-50-ml/NATBRA-189563
# [58/276] ok - https://www.natura.com.br/p/hidratante-facial-matificante-faces-50-ml/NATBRA-166353
# [59/276] ok - https://www.natura.com.br/p/hidratante-facial-pele-normal-a-seca-faces-50-ml/NATBRA-91820
# [60/276] ok - https://www.natura.com.br/p/iluminador-para-rosto,-olhos-e-boca-humor-festival-9-g/NATBRA-179460
# [61/276] descartado - https://www.natura.com.br/p/iluminador-rosto-e-corpo-una-30-ml/NATBRA-95978
# [62/276] descartado - https://www.natura.com.br/p/kit-antiqueda-e-crescimento-lumina-com-shampoo-e-serum/NATBRA-194391
# [63/276] descartado - https://www.natura.com.br/p/kit-basico-para-o-dia-a-dia-chronos-derma-(2-produtos)/NATBRA-219716
# [64/276] descartado - https://www.natura.com.br/p/kit-condicionador-protetor-lumina-para-hidratacao-e-protecao-antipoluicao-com-refil-2-un-de-300-ml/NATBRA-219733
# [65/276] descartado - https://www.natura.com.br/p/kit-creme-antissinais-60+-dia-chronos-derma-com-refil/NATBRA-228438
# [66/276] descartado - https://www.natura.com.br/p/kit-creme-antissinais-60+-noite-chronos-derma-com-refil/NATBRA-228439
# [67/276] descartado - https://www.natura.com.br/p/kit-creme-antissinais-70+-dia-chronos-derma-com-refil/NATBRA-228440
# [68/276] descartado - https://www.natura.com.br/p/kit-creme-antissinais-70+-noite-chronos-derma-com-refil/NATBRA-228441
# [69/276] descartado - https://www.natura.com.br/p/kit-creme-antissinais-80+-dia-chronos-derma-com-refil/NATBRA-228442
# [70/276] descartado - https://www.natura.com.br/p/kit-creme-antissinais-80+-noite-chronos-derma-com-refil/NATBRA-228443
# [71/276] descartado - https://www.natura.com.br/p/kit-dupla-antissinais-30+-chronos-derma-(2-produtos)/NATBRA-219703
# [72/276] descartado - https://www.natura.com.br/p/kit-dupla-antissinais-45+-chronos-derma-(2-produtos)/NATBRA-219704
# [73/276] descartado - https://www.natura.com.br/p/kit-dupla-antissinais-60+-chronos-derma-(-2-produtos)/NATBRA-219705
# [74/276] descartado - https://www.natura.com.br/p/kit-dupla-antissinais-70+-chronos-derma-(2-produtos)/NATBRA-219706
# [75/276] descartado - https://www.natura.com.br/p/kit-dupla-antissinais-80+-chronos-derma-(2-produtos)/NATBRA-219707
# [76/276] descartado - https://www.natura.com.br/p/kit-ekos-cacau-hidratante-e-protetor-labial-(2-produtos)/NATBRA-216031
# [77/276] descartado - https://www.natura.com.br/p/kit-ekos-murumuru-shampoo,-condicionador,-mascara-e-creme-para-pentear-(4-produtos)/NATBRA-217209
# [78/276] descartado - https://www.natura.com.br/p/kit-ekos-murumuru-shampoo,-condicionador,-mascara-e-serum-(4-produtos)/NATBRA-218171
# [79/276] descartado - https://www.natura.com.br/p/kit-ekos-murumuru-shampoo,-condicionador-e-mascara-(3-produtos)/NATBRA-217210
# [80/276] descartado - https://www.natura.com.br/p/kit-ekos-murumuru-shampoo,-condicionador-e-serum-(3-produtos)/NATBRA-218170
# [81/276] descartado - https://www.natura.com.br/p/kit-ekos-pataua,-shampoo,-condicionador,-mascara-e-oleo-(4-produtos)/NATBRA-218173
# [82/276] descartado - https://www.natura.com.br/p/kit-ekos-pataua,-shampoo,-condicionador-e-mascara-(3-produtos)/NATBRA-218175
# [83/276] descartado - https://www.natura.com.br/p/kit-ekos-pataua-shampoo,-condicionador,-mascara-e-tonico-(4-produtos)/NATBRA-218177
# [84/276] descartado - https://www.natura.com.br/p/kit-faces-caneta-delineadora-preta-e-mascara-incolor-(2-produtos)/NATBRA-218186
# [85/276] descartado - https://www.natura.com.br/p/kit-faces-lapis-para-olhos-preto-e-supermascara-tint-para-cilios-(2-produtos)/NATBRA-218185
# [86/276] descartado - https://www.natura.com.br/p/kit-gel-creme-antissinais-30+-dia-chronos-derma-com-refil/NATBRA-228434
# [87/276] descartado - https://www.natura.com.br/p/kit-gel-creme-antissinais-30+-noite-chronos-derma-com-refil/NATBRA-228435
# [88/276] descartado - https://www.natura.com.br/p/kit-gel-creme-antissinais-45+-dia-chronos-derma-com-refil/NATBRA-228436
# [89/276] descartado - https://www.natura.com.br/p/kit-gel-creme-antissinais-45+-noite-chronos-derma-com-refil/NATBRA-228437
# [90/276] descartado - https://www.natura.com.br/p/kit-hidratante-acqua-renovador-chronos-derma-com-refil-2-un-de-40-g/NATBRA-221664
# [91/276] descartado - https://www.natura.com.br/p/kit-limpeza-intensiva-chronos-derma-(2-produtos)/NATBRA-218213
# [92/276] descartado - https://www.natura.com.br/p/kit-limpeza-suave-chronos-derma-(2-produtos)/NATBRA-218212
# [93/276] descartado - https://www.natura.com.br/p/kit-lumina-brilho-e-protecao-da-cor-shampoo,-condicionador-e-mascara-(3-produtos)/NATBRA-217207
# [94/276] descartado - https://www.natura.com.br/p/kit-lumina-cabelos-crespos-shampoo,-condicionador-e-mascara-(3-produtos)/NATBRA-217198
# [95/276] descartado - https://www.natura.com.br/p/kit-lumina-cacheados-shampoo,-condicionador,-mascara-e-creme-de-pentear-(4-produtos)/NATBRA-217203
# [96/276] descartado - https://www.natura.com.br/p/kit-lumina-cacheados-shampoo,-condicionador-e-mascara-(3-produtos)/NATBRA-217201
# [97/276] descartado - https://www.natura.com.br/p/kit-lumina-nutricao-e-reparacao-shampoo,-condicionador-e-mascara-(3-produtos)/NATBRA-217191
# [98/276] descartado - https://www.natura.com.br/p/kit-mascara-e-spray-lumina-para-restauracao-e-liso-prolongado-(2-produtos)/NATBRA-221666
# [99/276] descartado - https://www.natura.com.br/p/kit-mascara-nutricao-e-reparacao-profunda-lumina-com-refil-2-un-de-250-ml/NATBRA-185536
# [100/276] descartado - https://www.natura.com.br/p/kit-mascaras-portateis-lumina-(3-produtos)/NATBRA-229960
# [101/276] descartado - https://www.natura.com.br/p/kit-potencia-para-flacidez-chronos-derma-(2-produtos)/NATBRA-218214
# [102/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-corporal-fps-30-e-gel-hidratante-pos-sol-natura-solar/NATBRA-231691
# [103/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-corporal-fps-50-e-gel-hidratante-pos-sol-natura-solar/NATBRA-231687
# [104/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-corporal-fps-50-e-gel-hidratante-pos-sol-natura-solar/NATBRA-231693
# [105/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-pele-mista-a-oleosa-e-protetor-solar-corporal-fps-50-natura-solar/NATBRA-231697
# [106/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-pele-mista-a-oleosa-e-protetor-solar-corporal-fps-70-natura-solar/NATBRA-231701
# [107/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-pele-normal-a-seca-e-protetor-solar-corporal-fps-50-natura-solar/NATBRA-231703
# [108/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-pele-normal-a-seca-e-protetor-solar-corporal-fps-50-natura-solar/NATBRA-231705
# [109/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-stick-e-protetor-solar-corporal-fps-50-com-acessorio-natura-solar/NATBRA-231698
# [110/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-stick-e-protetor-solar-corporal-fps-50-natura-solar/NATBRA-231707
# [111/276] descartado - https://www.natura.com.br/p/kit-protetor-solar-facial-stick-fps-50-e-necessaire-natura-solar/NATBRA-231700
# [112/276] descartado - https://www.natura.com.br/p/kit-refil-mascara-concentrada-cronocapilar-tododia-3-un-de-250-ml/NATBRA-204410
# [113/276] descartado - https://www.natura.com.br/p/kit-refil-shampoo,-condicionador-e-mascara-lumina-para-restauracao-e-liso-prolongado/NATBRA-229973
# [114/276] descartado - https://www.natura.com.br/p/kit-rotina-antioleosidade-chronos-derma-(2-produtos)/NATBRA-219713
# [115/276] descartado - https://www.natura.com.br/p/kit-rotina-antirugas-chronos-derma-(2-produtos)/NATBRA-219714
# [116/276] descartado - https://www.natura.com.br/p/kit-rotina-de-limpeza-chronos-derma-(2-produtos)/NATBRA-219715
# [117/276] descartado - https://www.natura.com.br/p/kit-rotina-flacidez-chronos-derma-(3-produtos)/NATBRA-218219
# [118/276] descartado - https://www.natura.com.br/p/kit-rotina-hidratacao-chronos-derma-(3-produtos)/NATBRA-218217
# [119/276] descartado - https://www.natura.com.br/p/kit-rotina-hidratacao-completo-chronos-derma-(4-produtos)/NATBRA-218218
# [120/276] descartado - https://www.natura.com.br/p/kit-rotina-para-pele-oleosa-chronos-derma-(3-produtos)/NATBRA-232528
# [121/276] descartado - https://www.natura.com.br/p/kit-rotina-prevencao-chronos-derma-(3-produtos)/NATBRA-219702
# [122/276] descartado - https://www.natura.com.br/p/kit-rotina-rugas-super-chronos-derma-(3-produtos)/NATBRA-218215
# [123/276] descartado - https://www.natura.com.br/p/kit-sabonete-facial-esfoliante-e-multicorretor-antissinais-natura-homem-(2-produtos)/NATBRA-219744
# [124/276] descartado - https://www.natura.com.br/p/kit-shampoo,-condicionador-e-mascara-lumina-forca-e-reparacao-molecular-(3-produtos)/NATBRA-208138
# [125/276] descartado - https://www.natura.com.br/p/kit-shampoo,-condicionador-e-mascara-lumina-para-restauracao-e-liso-prolongado-(3-produtos)/NATBRA-221668
# [126/276] descartado - https://www.natura.com.br/p/kit-shampoo-e-mascara-lumina-para-nutricao-e-reparacao-profunda-(2-produtos)/NATBRA-211657
# [127/276] descartado - https://www.natura.com.br/p/kit-shampoo-e-mascara-nutricao-e-reparacao/NATBRA-167104
# [128/276] descartado - https://www.natura.com.br/p/kit-shampoo-e-mascara-reconstrucao-de-danos-extremos/NATBRA-167106
# [129/276] descartado - https://www.natura.com.br/p/kit-spray-de-volume-e-protetor-termico-para-finalizacao-lumina-(2-produtos)/NATBRA-213218
# [130/276] descartado - https://www.natura.com.br/p/kit-spray-texturizador-e-protetor-termico-para-finalizacao-lumina-(2-produtos)/NATBRA-213219
# [131/276] descartado - https://www.natura.com.br/p/kit-super-serum-redutor-de-rugas-chronos-derma-com-refil/NATBRA-212742
# [132/276] descartado - https://www.natura.com.br/p/kit-tododia-mascaras-reparacao,-nutricao-e-hidratacao/NATBRA-177694
# [133/276] descartado - https://www.natura.com.br/p/kit-una-caneta-delineadora-preta-e-mascara-para-cilios-2-em-1-(2-produtos)/NATBRA-218183
# [134/276] ok - https://www.natura.com.br/p/locao-protetora-crianca-fps-60-fpuva-20-fotoequilibrio-120-ml/NATBRA-103136
# [135/276] ok - https://www.natura.com.br/p/locao-protetora-fps-30-fpuva-10-fotoequilibrio-120-ml/NATBRA-103134
# [136/276] ok - https://www.natura.com.br/p/locao-protetora-fps-60-fpuva-20-fotoequilibrio-200-ml/NATBRA-103140
# [137/276] ok - https://www.natura.com.br/p/mascara-antiquebra-antiqueda-e-crescimento-lumina-250-ml/NATBRA-147417
# [138/276] ok - https://www.natura.com.br/p/mascara-antiquebra-lumina-para-antiqueda-e-crescimento-50-ml/NATBRA-150302
# [139/276] descartado - https://www.natura.com.br/p/mascara-concentrada-crono-capilar-tododia-hidrata-250-ml/NATBRA-154871
# [140/276] descartado - https://www.natura.com.br/p/mascara-concentrada-crono-capilar-tododia-nutre-250-ml/NATBRA-154872
# [141/276] descartado - https://www.natura.com.br/p/mascara-concentrada-crono-capilar-tododia-repara-250-ml/NATBRA-154875
# [142/276] ok - https://www.natura.com.br/p/mascara-de-argila-purificante-chronos-70-g/NATBRA-69724
# [143/276] ok - https://www.natura.com.br/p/mascara-de-blindagem-para-cabelos-opacos-ou-com-coloracao-lumina-220-ml/NATBRA-148410
# [144/276] ok - https://www.natura.com.br/p/mascara-esfoliante-renova+-faces-50-ml/NATBRA-166350
# [145/276] ok - https://www.natura.com.br/p/mascara-facial-hidra-glow-faces-50-ml/NATBRA-128423
# [146/276] ok - https://www.natura.com.br/p/mascara-facial-hidratante-pre-make-faces-20-ml/NATBRA-183308
# [147/276] ok - https://www.natura.com.br/p/mascara-facial-refrescante-faces-20-ml/NATBRA-183307
# [148/276] ok - https://www.natura.com.br/p/mascara-forca-e-reparacao-molecular-lumina-250-ml/NATBRA-164505
# [149/276] ok - https://www.natura.com.br/p/mascara-fortalecedora-ekos-pataua-200-g/NATBRA-112764
# [150/276] ok - https://www.natura.com.br/p/mascara-hidratante-refresh-faces-50-ml/NATBRA-105024
# [151/276] ok - https://www.natura.com.br/p/mascara-intensa-hidratacao-reparadora-plant-250-g/NATBRA-51881
# [152/276] ok - https://www.natura.com.br/p/mascara-lumina-restauradora-para-restauracao-e-liso-prolongado-250-ml/NATBRA-167289
# [153/276] ok - https://www.natura.com.br/p/mascara-mega-fantastica-preta-faces-7-ml/NATBRA-67666
# [154/276] ok - https://www.natura.com.br/p/mascara-para-cilios-2-em-1-una-8-ml/NATBRA-106123
# [155/276] ok - https://www.natura.com.br/p/mascara-para-cilios-alongamento-infinito-a-prova-d’agua-una-8-ml/NATBRA-106122
# [156/276] ok - https://www.natura.com.br/p/mascara-para-cilios-multi-hd-una-9-g/NATBRA-174921
# [157/276] ok - https://www.natura.com.br/p/mascara-para-cilios-volume-magnifico-a-prova-d’agua-una-8-ml/NATBRA-106121
# [158/276] ok - https://www.natura.com.br/p/mascara-para-cilios-volume-magnifico-lavavel-una-8-ml/NATBRA-106120
# [159/276] ok - https://www.natura.com.br/p/mascara-para-olhos-e-sobrancelhas-incolor-faces-7-ml/NATBRA-67647
# [160/276] ok - https://www.natura.com.br/p/mascara-para-sobrancelhas-faces/NATBRA-120447
# [161/276] ok - https://www.natura.com.br/p/mascara-reconstrutora-ekos-murumuru-200-g/NATBRA-112758
# [162/276] descartado - https://www.natura.com.br/p/mascara-reconstrutora-para-cabelos-crespos-lumina-250-ml/NATBRA-148417
# [163/276] descartado - https://www.natura.com.br/p/mascara-recuperadora-para-cabelos-cacheados-lumina-250-ml/NATBRA-148440
# [164/276] ok - https://www.natura.com.br/p/mascara-regeneradora-lumina-para-reconstrucao-de-danos-extremos-50-ml/NATBRA-150304
# [165/276] ok - https://www.natura.com.br/p/mascara-regeneradora-para-cabelos-quimicamente-danificados-lumina-250-ml/NATBRA-148412
# [166/276] ok - https://www.natura.com.br/p/mascara-reparadora-lumina-para-nutricao-e-reparacao-profunda-50-ml/NATBRA-150303
# [167/276] descartado - https://www.natura.com.br/p/mascara-reparadora-para-cabelos-secos-lumina-250-ml/NATBRA-86955
# [168/276] ok - https://www.natura.com.br/p/mascara-reparadora-para-cabelos-secos-ou-ressecados-lumina-250-ml/NATBRA-147418
# [169/276] ok - https://www.natura.com.br/p/mascara-volume-boost-para-cilios-faces-7-ml/NATBRA-110262
# [170/276] ok - https://www.natura.com.br/p/mascara-volume-fever-faces-7-ml/NATBRA-86642
# [171/276] ok - https://www.natura.com.br/p/multicorretor-antissinais-natura-homem-40-g/NATBRA-151019
# [172/276] ok - https://www.natura.com.br/p/multimascara-tint-para-cilios-a-prova-d’agua-faces-7-ml/NATBRA-9833
# [173/276] ok - https://www.natura.com.br/p/multiprotetor-antissinais-fps-50-chronos-50-ml/NATBRA-134189
# [174/276] descartado - https://www.natura.com.br/p/presente-natura-chronos-biohidratacao-e-acqua/NATBRA-159906
# [175/276] ok - https://www.natura.com.br/p/protetor-antioleosidade-redutor-de-poros-fps-30-fpuva-10-chronos-derma-50-ml/NATBRA-69725
# [176/276] ok - https://www.natura.com.br/p/protetor-clareador-fps-70-chronos-derma-50-ml/NATBRA-69049
# [177/276] duplicado - https://www.natura.com.br/p/protetor-clareador-fps-70-chronos-derma-50-ml/NATBRA-89247
# [178/276] duplicado - https://www.natura.com.br/p/protetor-clareador-fps-70-chronos-derma-50-ml/NATBRA-PAI69049
# [179/276] ok - https://www.natura.com.br/p/protetor-facial-gel-creme-fps-30-fpuva-10-fotoequilibrio-50-g/NATBRA-103142
# [180/276] ok - https://www.natura.com.br/p/protetor-facial-gel-creme-fps-60-fpuva-20-fotoequilibrio-50-g/NATBRA-103144
# [181/276] ok - https://www.natura.com.br/p/protetor-facial-locao-fps-30-fpuva-10-fotoequilibrio-50-g/NATBRA-103143
# [182/276] ok - https://www.natura.com.br/p/protetor-labial-hidratante-ekos-cacau-3,5-g/NATBRA-162315
# [183/276] descartado - https://www.natura.com.br/p/protetor-solar-corporal-fps-30-natura-solar-200-ml/NATBRA-182087
# [184/276] descartado - https://www.natura.com.br/p/protetor-solar-corporal-fps-50-natura-solar-120-ml/NATBRA-178864
# [185/276] descartado - https://www.natura.com.br/p/protetor-solar-corporal-fps-50-natura-solar-200-ml/NATBRA-176914
# [186/276] descartado - https://www.natura.com.br/p/protetor-solar-corporal-fps-70-natura-solar-200-ml/NATBRA-176908
# [187/276] ok - https://www.natura.com.br/p/protetor-solar-facial-pele-mista-a-oleosa-fps-50-natura-solar-50-ml/NATBRA-176909
# [188/276] ok - https://www.natura.com.br/p/protetor-solar-facial-pele-mista-a-oleosa-fps-70-natura-solar-50-ml/NATBRA-186435
# [189/276] ok - https://www.natura.com.br/p/protetor-solar-facial-pele-normal-a-seca-fps-50-natura-solar-50-ml/NATBRA-176913
# [190/276] ok - https://www.natura.com.br/p/protetor-solar-facial-pele-normal-a-seca-fps-70-natura-solar-50-ml/NATBRA-176905
# [191/276] ok - https://www.natura.com.br/p/protetor-solar-facial-stick-fps-50-natura-solar-15-g/NATBRA-178858
# [192/276] ok - https://www.natura.com.br/p/protetor-termico-forca-e-reparacao-molecular-lumina-150-ml/NATBRA-164518
# [193/276] ok - https://www.natura.com.br/p/protetor-termico-lumina-150-ml/NATBRA-148459
# [194/276] descartado - https://www.natura.com.br/p/refil-agua-micelar-demaquilante-suave-chronos-derma-150-ml/NATBRA-134588
# [195/276] descartado - https://www.natura.com.br/p/refil-agua-micelar-purificante-chronos-150-ml/NATBRA-69058
# [196/276] descartado - https://www.natura.com.br/p/refil-condicionador-protetor-hidratacao-e-protecao-antipoluicao-lumina/NATBRA-147402
# [197/276] descartado - https://www.natura.com.br/p/refil-condicionador-protetor-para-cabelo-liso-lumina-300ml/NATBRA-86969
# [198/276] descartado - https://www.natura.com.br/p/refil-condicionador-protetor-para-cabelos-opacos-ou-com-coloracao-lumina/NATBRA-148405
# [199/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-60+-dia-40-g/NATBRA-57993
# [200/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-60+-noite-40-g/NATBRA-58003
# [201/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-70+-dia-40-g/NATBRA-57987
# [202/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-70+-noite-40-g/NATBRA-58005
# [203/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-fortalecimento-e-nutricao-80+-dia-chronos-derma-40-g/NATBRA-134694
# [204/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-fortalecimento-e-nutricao-80+-noite-chronos-derma-40-g/NATBRA-134594
# [205/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-preenchimento-e-revitalizacao-60+-dia-chronos-derma-40-g/NATBRA-134700
# [206/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-preenchimento-e-revitalizacao-60+-noite-chronos-derma-40-g/NATBRA-134587
# [207/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-restauracao-e-cuidado-70+-dia-chronos-derma-40-g/NATBRA-134723
# [208/276] descartado - https://www.natura.com.br/p/refil-creme-antissinais-restauracao-e-cuidado-70+-noite-chronos-derma-40-g/NATBRA-134590
# [209/276] descartado - https://www.natura.com.br/p/refil-essencia-de-tratamento-revitalizacao-e-luminosidade-chronos-derma-100-ml/NATBRA-135037
# [210/276] descartado - https://www.natura.com.br/p/refil-fluido-bifasico-demaquilante-intensivo-chronos-derma-150-ml/NATBRA-135058
# [211/276] descartado - https://www.natura.com.br/p/refil-gel-creme-45+-dia-antissinais-firmeza-e-radiancia-chronos-40-g/NATBRA-57998
# [212/276] descartado - https://www.natura.com.br/p/refil-gel-creme-antissinais-30+-dia-40-g/NATBRA-57995
# [213/276] descartado - https://www.natura.com.br/p/refil-gel-creme-antissinais-firmeza-e-luminosidade-45+-dia-chronos-derma-40-g/NATBRA-134585
# [214/276] descartado - https://www.natura.com.br/p/refil-gel-creme-antissinais-firmeza-e-luminosidade-45+-noite-chronos-derma-40-g/NATBRA-134589
# [215/276] descartado - https://www.natura.com.br/p/refil-gel-creme-antissinais-renovacao-e-prevencao-30+-dia-chronos-derma-40-g/NATBRA-134591
# [216/276] descartado - https://www.natura.com.br/p/refil-gel-creme-antissinais-renovacao-e-prevencao-30+-noite-chronos-derma-40-g/NATBRA-134595
# [217/276] descartado - https://www.natura.com.br/p/refil-hidratante-acqua-renovador-chronos-derma-40-g/NATBRA-91819
# [218/276] descartado - https://www.natura.com.br/p/refil-iluminador-marmorizado-corpo-e-rosto/NATBRA-24865
# [219/276] descartado - https://www.natura.com.br/p/refil-mascara-antiquebra-antiqueda-e-crescimento-lumina/NATBRA-147407
# [220/276] descartado - https://www.natura.com.br/p/refil-mascara-concentrada-cronocapilar-tododia-hidrata-250-ml/NATBRA-154862
# [221/276] descartado - https://www.natura.com.br/p/refil-mascara-concentrada-cronocapilar-tododia-nutre-250-ml/NATBRA-154863
# [222/276] descartado - https://www.natura.com.br/p/refil-mascara-concentrada-cronocapilar-tododia-repara-250-ml/NATBRA-154864
# [223/276] descartado - https://www.natura.com.br/p/refil-mascara-de-blindagem-para-cabelos-opacos-ou-com-coloracao-lumina/NATBRA-148444
# [224/276] descartado - https://www.natura.com.br/p/refil-mascara-forca-e-reparacao-molecular-250-ml/NATBRA-164506
# [225/276] descartado - https://www.natura.com.br/p/refil-mascara-lumina-restauradora-para-restauracao-e-liso-prolongado-250-ml/NATBRA-167295
# [226/276] descartado - https://www.natura.com.br/p/refil-mascara-reconstrutora-para-cabelos-crespos-lumina-250-ml/NATBRA-148439
# [227/276] descartado - https://www.natura.com.br/p/refil-mascara-recuperadora-para-cabelos-cacheados-lumina-250-ml/NATBRA-148406
# [228/276] descartado - https://www.natura.com.br/p/refil-mascara-regeneradora-para-cabelos-quimicamente-danificados-lumina-250-ml/NATBRA-86954
# [229/276] descartado - https://www.natura.com.br/p/refil-mascara-regeneradora-para-cabelos-quimicamente-danificados-lumina/NATBRA-148443
# [230/276] descartado - https://www.natura.com.br/p/refil-mascara-reparadora-para-cabelos-secos-ou-ressecados-lumina/NATBRA-147447
# [231/276] descartado - https://www.natura.com.br/p/refil-sabonete-em-espuma-limpeza-suave-chronos-derma-150-ml/NATBRA-137981
# [232/276] descartado - https://www.natura.com.br/p/refil-serum-intensivo-antioxidante-chronos-derma-15-ml/NATBRA-169223
# [233/276] descartado - https://www.natura.com.br/p/refil-serum-intensivo-lifting-e-firmeza-chronos-derma-30-ml/NATBRA-168819
# [234/276] descartado - https://www.natura.com.br/p/refil-serum-intensivo-multiclareador-chronos-derma-30-ml/NATBRA-169235
# [235/276] descartado - https://www.natura.com.br/p/refil-serum-intensivo-preenchedor-hidratante-chronos-derma-30-ml/NATBRA-168818
# [236/276] descartado - https://www.natura.com.br/p/refil-serum-intensivo-redutor-de-oleosidade-chronos-derma-30-ml/NATBRA-169244
# [237/276] descartado - https://www.natura.com.br/p/refil-super-serum-para-olhos-redutor-de-rugas-e-flacidez-chronos-derma-15-ml/NATBRA-169238
# [238/276] descartado - https://www.natura.com.br/p/refil-super-serum-redutor-de-rugas-chronos-derma-30-ml/NATBRA-169234
# [239/276] ok - https://www.natura.com.br/p/sabonete-creme-limpeza-hidratante-chronos-115-ml/NATBRA-59374
# [240/276] ok - https://www.natura.com.br/p/sabonete-em-espuma-limpeza-suave-chronos-derma-150-ml/NATBRA-135060
# [241/276] ok - https://www.natura.com.br/p/sabonete-em-gel-limpeza-purificante-antioleosidade-chronos-derma-130-g/NATBRA-69720
# [242/276] ok - https://www.natura.com.br/p/sabonete-em-mousse-limpeza-intensiva-chronos-derma-85-g/NATBRA-134586
# [243/276] ok - https://www.natura.com.br/p/sabonete-em-oleo-limpeza-demaquilante-chronos-derma-125-ml/NATBRA-171365
# [244/276] ok - https://www.natura.com.br/p/sabonete-em-oleo-limpeza-demaquilante-miniatura-chronos-derma-50-ml/NATBRA-167237
# [245/276] ok - https://www.natura.com.br/p/sabonete-esfoliante-para-o-rosto-biome-65-g/NATBRA-124834
# [246/276] ok - https://www.natura.com.br/p/sabonete-facial-cremoso-biome-65-g/NATBRA-124833
# [247/276] ok - https://www.natura.com.br/p/sabonete-facial-esfoliante-natura-homem-75-ml/NATBRA-160273
# [248/276] ok - https://www.natura.com.br/p/sabonete-gel-para-o-rosto-faces-120-g/NATBRA-90175
# [249/276] descartado - https://www.natura.com.br/p/sabonete-liquido-para-corpo-e-rosto-natura-homem-cor.agio-100-ml/NATBRA-114273
# [250/276] ok - https://www.natura.com.br/p/serum-facial-uniformizador-uniformiza+-faces-35-g/NATBRA-166354
# [251/276] ok - https://www.natura.com.br/p/serum-intensivo-antioxidante-chronos-15-ml/NATBRA-131456
# [252/276] ok - https://www.natura.com.br/p/serum-intensivo-antioxidante-chronos-derma-15-ml/NATBRA-169245
# [253/276] ok - https://www.natura.com.br/p/serum-intensivo-lifting-&-firmeza-chronos-30-ml/NATBRA-108636
# [254/276] ok - https://www.natura.com.br/p/serum-intensivo-lifting-e-firmeza-chronos-derma-30-ml/NATBRA-169247
# [255/276] ok - https://www.natura.com.br/p/serum-intensivo-multiclareador-chronos-30-g/NATBRA-80060
# [256/276] ok - https://www.natura.com.br/p/serum-intensivo-multiclareador-chronos-derma-30-ml/NATBRA-169222
# [257/276] ok - https://www.natura.com.br/p/serum-intensivo-para-bolsas-e-olheiras-natura-chronos-15-ml/NATBRA-127754
# [258/276] ok - https://www.natura.com.br/p/serum-intensivo-preenchedor-hidratante-chronos-derma-30-ml/NATBRA-169233
# [259/276] ok - https://www.natura.com.br/p/serum-intensivo-redutor-de-oleosidade-chronos-derma-30-ml/NATBRA-169229
# [260/276] ok - https://www.natura.com.br/p/serum-labial-incolor-una-1,8-g/NATBRA-106294
# [261/276] ok - https://www.natura.com.br/p/serum-noturno-antioleosidade-e-poros-chronos-30-ml/NATBRA-69723
# [262/276] ok - https://www.natura.com.br/p/serum-noturno-antiqueda-e-crescimento-lumina-100-ml/NATBRA-147427
# [263/276] ok - https://www.natura.com.br/p/serum-noturno-forca-e-reparacao-molecular-lumina-100-ml/NATBRA-164508
# [264/276] ok - https://www.natura.com.br/p/serum-noturno-nutritivo-ekos-murumuru-30-ml/NATBRA-112890
# [265/276] ok - https://www.natura.com.br/p/serum-para-sobrancelhas-una-4-g/NATBRA-140742
# [266/276] ok - https://www.natura.com.br/p/serum-para-unhas-e-cuticulas-una-10-ml/NATBRA-109481
# [267/276] ok - https://www.natura.com.br/p/serum-preenchedor-biohidratante-chronos-30-ml/NATBRA-108634
# [268/276] ok - https://www.natura.com.br/p/serum-regenerador-progressivo-para-cabelos-quimicamente-danificados-lumina-100-ml/NATBRA-148421
# [269/276] ok - https://www.natura.com.br/p/super-serum-para-olhos-redutor-de-rugas-e-flacidez-chronos-derma-15-ml/NATBRA-169258
# [270/276] ok - https://www.natura.com.br/p/super-serum-redutor-de-rugas-chronos-30-ml/NATBRA-96735
# [271/276] ok - https://www.natura.com.br/p/super-serum-redutor-de-rugas-chronos-derma-30-ml/NATBRA-169264
# [272/276] ok - https://www.natura.com.br/p/supermascara-tint-para-cilios-faces-12-ml/NATBRA-9832
# [273/276] ok - https://www.natura.com.br/p/tonico-detox-hidratante-chronos-150-ml/NATBRA-59375
# [274/276] ok - https://www.natura.com.br/p/triplo-esfoliante-peeling-antissinais-chronos-derma-50-g/NATBRA-135057
# [275/276] ok - https://www.natura.com.br/p/triplo-esfoliante-peeling-antissinais-miniatura-chronos-derma-15-g/NATBRA-147461
# [276/276] ok - https://www.natura.com.br/p/una-mascara-de-cilios-volume-magnifico-8-ml/NATBRA-156124
# Salvo JSON: natura_products.json
# Salvo CSV : natura_products.csv
# Itens válidos: 116
